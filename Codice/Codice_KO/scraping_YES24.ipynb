# %%
import re
import time
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
PATH='C:\\Users\\Fossati\\Desktop\\Tesi_Ale\\chromedriver91.exe'
driver = webdriver.Chrome(PATH)

# %%
#import korean metadata

# %%
meta_ko=pd.read_csv("\\Users\\Fossati\\Desktop\\Tesi_Ale\\Codice\\Codice_KO\\Metadati_KO.csv")
meta_ko
#per koreano tengo tutto in una cartella unica con codici e file, così da avere tutto li anche in vista della pulizia della cartella
# Out:
#      Unnamed: 0  index        Genere       Title           ISBN        Author  \
# 0             0      0  Children_Lit   푸른 사자 와니니  9788936442804            이현
# 1             1      1  Children_Lit     만복이네 떡집  9788949161341           김리리
# 2             2      2  Children_Lit     장군이네 떡집  9788949162041           김리리
# 3             3      3  Children_Lit  아홉 살 마음 사전  9788936447014           박성우
# 4             4      4  Children_Lit       소원 떡집  9788949162058           김리리
# ..          ...    ...           ...         ...            ...           ...
# 995         995   1619         Scify      위대한 침묵  9791196250133           해도연
# 996         996   1621         Scify  우주아이돌 배달작전  9791196250119           손지상
# 997         997   1623         Scify     헬로 아메리카  9788972759416  제임스 그레이엄 밸러드
# 998         998   1628         Scify       변화의 땅  9788995529744       로저 젤라즈니
# 999         999   1633         Scify      잠자는 거인  9788931011081         실뱅 누벨
#
#        Price                                            Shelves N_pag  \
# 0     9,720원  ['카테고리 분류\n  국내도서 > 어린이 > 3-4학년 > 3-4학년 그림/동화책...   216
# 1     8,550원  ['카테고리 분류\n  국내도서 > 어린이 > 1-2학년 > 1-2학년 그림/동화책...    56
# 2     8,550원  ['카테고리 분류\n  국내도서 > 어린이 > 1-2학년 > 1-2학년 그림/동화책...    84
# 3     9,900원  ['카테고리 분류\n  국내도서 > 어린이 > 3-4학년 > 3-4학년 그림/동화책...   168
# 4     8,550원  ['카테고리 분류\n  국내도서 > 어린이 > 1-2학년 > 1-2학년 그림/동화책...    84
# ..       ...                                                ...   ...
# 995  11,700원  ['카테고리 분류\n  국내도서 > 소설/시/희곡 > 장르소설 > SF\n  국내도...   298
# 996  10,800원  ['카테고리 분류\n  국내도서 > 소설/시/희곡 > 장르소설 > SF\n  국내도...   270
# 997  12,600원  ['카테고리 분류\n  국내도서 > 소설/시/희곡 > 장르소설 > SF\n  국내도...   404
# 998   9,000원  ['카테고리 분류\n  국내도서 > 소설/시/희곡 > 장르소설 > 판타지\n  국내...   351
# 999  13,500원  ['카테고리 분류\n  국내도서 > 소설/시/희곡 > 장르소설 > SF\n  국내도...   344
#
#      Pub_Date  ...  Overall_Rating  Overall_Rating_ol  \
# 0        2015  ...             9.3                9.6
# 1        2010  ...             9.6                9.6
# 2        2020  ...             9.6                9.8
# 3        2017  ...             9.4                9.6
# 4        2020  ...             9.6                9.6
# ..        ...  ...             ...                ...
# 995      2018  ...             9.1               10.0
# 996      2018  ...             9.0              error
# 997      2019  ...             8.6               10.0
# 998      2005  ...             7.8              error
# 999      2018  ...             8.4              error
#
#                                         Yes_link Tot_Reviews  Prezzo_Naver  \
# 0    http://www.yes24.com/Product/Goods/18841857         192          9.72
# 1     http://www.yes24.com/Product/Goods/3906369         322          8.55
# 2    http://www.yes24.com/Product/Goods/89938914         173          8.55
# 3    http://www.yes24.com/Product/Goods/37211852         549          9.90
# 4    http://www.yes24.com/Product/Goods/89938917         145          8.55
# ..                                           ...         ...           ...
# 995  http://www.yes24.com/Product/Goods/63009623           9         11.70
# 996  http://www.yes24.com/Product/Goods/59577050           6         10.80
# 997  http://www.yes24.com/Product/Goods/71751447          17         12.60
# 998   http://www.yes24.com/Product/Goods/1782383           5          9.00
# 999  http://www.yes24.com/Product/Goods/64340059           8         13.50
#
#     Pub_Date_Naver Overall_Rat_Naver  Num_Reviews_Naver  \
# 0       2019.01.29              8.83                 95
# 1       2010.05.28             10.00                 96
# 2       2020.04.29             10.00                 17
# 3       2017.03.10              9.54                134
# 4       2020.04.29             10.00                 21
# ..             ...               ...                ...
# 995     2018.08.01              9.50                  8
# 996     2018.03.28              5.50                  9
# 997     2019.03.29              8.67                 14
# 998     2005.09.12              7.43                  9
# 999     2018.08.30              8.00                  7
#
#                                             Naver_Link Reviews_Sum
# 0    http://book.naver.com/bookdb/book_detail.naver...         287
# 1    http://book.naver.com/bookdb/book_detail.naver...         418
# 2    http://book.naver.com/bookdb/book_detail.naver...         190
# 3    http://book.naver.com/bookdb/book_detail.naver...         683
# 4    http://book.naver.com/bookdb/book_detail.naver...         166
# ..                                                 ...         ...
# 995  http://book.naver.com/bookdb/book_detail.naver...          17
# 996  http://book.naver.com/bookdb/book_detail.naver...          15
# 997  http://book.naver.com/bookdb/book_detail.naver...          31
# 998  http://book.naver.com/bookdb/book_detail.naver...          14
# 999  http://book.naver.com/bookdb/book_detail.naver...          15
#
# [1000 rows x 24 columns]

# %%
# liste ad hoc 
title=meta_ko['Title'].to_list()
isbn=meta_ko['ISBN'].to_list()
gen=meta_ko['Genere'].to_list()
booklist=meta_ko['Yes_link'].to_list()

nrev_list=meta_ko['Num_Reviews'].to_list()
nrev_list_ol=meta_ko['Num_Reviews_ol'].to_list()

# %%
#queste altre liste servono per la prima parte dedicata alle reviews specifiche:
rev_content=[]
rev_ratings=[]
rev_date=[]
userlist=[]
n_likes=[]
#vanno fillate ogn i volta
titoli=[]
isbn_code=[]
genere=[]



#queste altre liste servono per la seconda parte dedicata alle reviews specifiche one line:
rev_content_ol=[]
rev_ratings_ol=[]
rev_date_ol=[]
userlist_ol=[]
n_likes_ol=[]
#vanno fillate ogni volta
titoli_ol=[]
isbn_code_ol=[]
genere_ol=[]

#devo fare in modo che i due dataset siamo separati ma che siano anche unibili in qualsiasi momento

# %%
intlist=[574, 876, 904, 949, 998, 999]
booklist[intlist[0]]
# Out:
# 'http://www.yes24.com/Product/Goods/15323325'

# %%
#codice scraping finale yes24


not_found=[]
#numero_libro=101  #porta a 101
#no_link+=1

for book in intlist:   #recupera 102-172
    
    time.sleep(2)
    numero_libro=book
    try:
        try:
            url= str(book)
            driver.get(url)
        except:
            time.sleep(5)
            url= str(book)
            driver.get(url)
    except:
        #no_link+=1
        not_found.append(numero_libro) #cosi sappiamo quali indici di libro perdiamo
        continue

    

    
    
    
    #REVIEWS LUNGHE:
    
    #number of reviews
    try:
        n_rev = driver.find_element_by_id('emReviewCountText').text
        n_rev=int(re.findall(r'\d+', n_rev)[0])
    except:
        n_rev=nrev_list[numero_libro]
    
    
    number=str(int(re.findall(r'\d+', book)[1]))#servirà poi per creare il link
    p1='http://www.yes24.com/Product/communityModules/GoodsReviewList/'
    p2=str(number)
    p3='?Sort=1&PageNumber='
    p5='&Type=ALL'
    
    
    if n_rev > 5: #se le reviews non sono solo ristrette in una pagina
    
        #page_link=driver.find_element_by_xpath("//div[@class='yesUI_pagenS']/a[@class='num']").get_attribute('href')
        #p1=page_link[0:88]  #si scinde il link per poter ciclare il numero di pagina
        #p2=page_link[89:]
        
        
        
        if n_rev//5 == n_rev/5:  #valuta se sono divisibili per 5 
    
            for i in range(1,int(n_rev/5 +1),1):  #5 reviews per pagina
                
                p4= str(i)
                url2=p1+p2+p3+p4+p5
                
                try:
                    try:
                        driver.get(url2)
                    except:
                        time.sleep(5)
                        driver.get(url2)
                except:
                    continue #lo balzi diretto, senza appendere gli errori che tanto poi li vai ad eliminare
                 

                
                
                #fissiamo il paletto di riferimento per le reviews lunghe
                try:
                    try:
                        members_rev=driver.find_element_by_xpath("//div[@class='infoSetCont_wrap reviewRow_cont tp_tab yesComLoadingArea']")
                    except:
                        time.sleep(5) 
                        members_rev=driver.find_element_by_xpath("//div[@class='infoSetCont_wrap reviewRow_cont tp_tab yesComLoadingArea']")
                except:
                    continue
                    
                    
                #cominciamo con il fillare la lista dei titoli, isbn e genere
                titoli.extend([title[numero_libro] for x in range(5)])
                isbn_code.extend([isbn[numero_libro] for x in range(5)])
                genere.extend([gen[numero_libro] for x in range(5)])
                
        
                #data
                try:
                    review_date=members_rev.find_elements_by_class_name('txt_date')
                    for el in review_date:
                        rev_date.append(el.text)
                    time.sleep(1)
            
                except:
                    rev_date.extend(['error' for x in range(5)])
                    time.sleep(2)
        
                #ratings
                try:
                    review_rating = members_rev.find_elements_by_class_name('review_rating') 
                    for el in review_rating:
                        rev_ratings.append(re.findall(r'\d+', el.text))
                    time.sleep(1)
                
                except:
                    rev_ratings.extend(['error' for x in range(5)])
                    time.sleep(2)
                    
                                        
                #n_likes
                
                try:
                    likes=members_rev.find_elements_by_class_name('yes_b.txt')
                    for el in likes:
                        n_likes.append(el.text)
                except:
                    n_likes.extend(['error' for x in range(5)])
            
            

            
                #contenuto
                try:
                    time.sleep(1)
                    review_cont = members_rev.find_elements_by_xpath("//div[@class='reviewInfoGrp lnkExtend']/div[@class='reviewInfoBot origin']/div[@class='review_cont']")
                    for el in review_cont:
                        review_content = el.get_attribute('textContent')
                        rev_content.append(review_content.strip())
                    time.sleep(1)
                
                except:
                    rev_content.extend(['error' for x in range(5)])
                    time.sleep(2)
            
                
                #username review
                try:
                    blog_lnk=driver.find_elements_by_xpath("//div[@class='reviewInfoGrp lnkExtend']/div[@class='reviewInfoBot origin']/div[@class='review_lnk']/p/a")
                    links_blog=[]
                    for el in blog_lnk:
                        links_blog.append(el.get_attribute('href'))
                    for el in links_blog:
                        try:
                            driver.get(str(el))
                            user=driver.find_element_by_id('ImgLayer').text
                            userlist.append(user)
                        except:
                            userlist.append('error')
                except:
                    userlist.append('error')
                    

                
                        
                        
                        
                        
        
        
        else:
            
            
            for i in range(1,int(n_rev/5 +2),1):  #5 reviews per pagina con l'ultima che potrebbe averne chissà quante
                
                p4= str(i)
                url2=p1+p2+p3+p4+p5
                
                try:
                    try:
                        driver.get(url2)
                    except:
                        time.sleep(5)
                        driver.get(url2)
                except:
                    continue #lo balzi diretto, senza appendere gli errori che tanto poi li vai ad eliminare
                 

                
                
                #fissiamo il paletto di riferimento per le reviews lunghe
                try:
                    try:
                        members_rev=driver.find_element_by_xpath("//div[@class='infoSetCont_wrap reviewRow_cont tp_tab yesComLoadingArea']")
                    except:
                        time.sleep(5) 
                        members_rev=driver.find_element_by_xpath("//div[@class='infoSetCont_wrap reviewRow_cont tp_tab yesComLoadingArea']")
                except:
                    continue
                    
                    
                #cominciamo con il fillare la lista dei titoli, isbn e genere
                titoli.extend([title[numero_libro] for x in range(5)])
                isbn_code.extend([isbn[numero_libro] for x in range(5)])
                genere.extend([gen[numero_libro] for x in range(5)])
                
        
                #data
                try:
                    review_date=members_rev.find_elements_by_class_name('txt_date')
                    for el in review_date:
                        rev_date.append(el.text)
                    time.sleep(1)
            
                except:
                    rev_date.extend(['error' for x in range(5)])
                    time.sleep(2)
        
                #ratings
                try:
                    review_rating = members_rev.find_elements_by_class_name('review_rating') 
                    for el in review_rating:
                        rev_ratings.append(re.findall(r'\d+', el.text))
                    time.sleep(1)
                
                except:
                    rev_ratings.extend(['error' for x in range(5)])
                    time.sleep(2)
                    
                                        
                #n_likes
                
                try:
                    likes=members_rev.find_elements_by_class_name('yes_b.txt')
                    for el in likes:
                        n_likes.append(el.text)
                except:
                    n_likes.extend(['error' for x in range(5)])
            
            

            
                #contenuto
                try:
                    time.sleep(1)
                    review_cont = members_rev.find_elements_by_xpath("//div[@class='reviewInfoGrp lnkExtend']/div[@class='reviewInfoBot origin']/div[@class='review_cont']")
                    for el in review_cont:
                        review_content = el.get_attribute('textContent')
                        rev_content.append(review_content.strip())
                    time.sleep(1)
                
                except:
                    rev_content.extend(['error' for x in range(5)])
                    time.sleep(2)
            
                
                #username review
                try:
                    blog_lnk=driver.find_elements_by_xpath("//div[@class='reviewInfoGrp lnkExtend']/div[@class='reviewInfoBot origin']/div[@class='review_lnk']/p/a")
                    links_blog=[]
                    for el in blog_lnk:
                        links_blog.append(el.get_attribute('href'))
                    for el in links_blog:
                        try:
                            driver.get(str(el))
                            user=driver.find_element_by_id('ImgLayer').text
                            userlist.append(user)
                        except:
                            userlist.append('error')
                except:
                    userlist.append('error')
                        
                        
    
    
    
    else: #se le reviews sono 5 o meno, quindi una sola pagina
        
            #fissiamo il paletto di riferimento per le reviews lunghe
            try:
                    try:
                        members_rev=driver.find_element_by_xpath("//div[@class='infoSetCont_wrap reviewRow_cont tp_tab yesComLoadingArea']")
                    except:
                        time.sleep(5) 
                        members_rev=driver.find_element_by_xpath("//div[@class='infoSetCont_wrap reviewRow_cont tp_tab yesComLoadingArea']")
            except:
                    continue
                    
            #cominciamo con il fillare la lista dei titoli, isbn e genere
            titoli.extend([title[numero_libro] for x in range(n_rev)])
            isbn_code.extend([isbn[numero_libro] for x in range(n_rev)])
            genere.extend([gen[numero_libro] for x in range(n_rev)])
        
            #data
            try:
                review_date=members_rev.find_elements_by_class_name('txt_date')
                for el in review_date:
                    rev_date.append(el.text)
                time.sleep(1)
            
            except:
                rev_date.extend(['error' for x in range(n_rev)])
                time.sleep(1)
        
            #ratings
            try:
                review_rating = members_rev.find_elements_by_class_name('review_rating') 
                for el in review_rating:
                    rev_ratings.append(re.findall(r'\d+', el.text))
                time.sleep(1)
                
            except:
                rev_ratings.extend(['error' for x in range(n_rev)])
            
                time.sleep(1)
                

            #n_likes
                
            try:
                    likes=members_rev.find_elements_by_class_name('yes_b.txt')
                    for el in likes:
                        n_likes.append(el.text)
            except:
                    n_likes.extend(['error' for x in range(n_rev)])            
            

            
            #contenuto
            try:
                review_cont = members_rev.find_elements_by_xpath("//div[@class='reviewInfoGrp lnkExtend']/div[@class='reviewInfoBot origin']/div[@class='review_cont']")
                for el in review_cont:
                    review_content = el.get_attribute('textContent')
                    rev_content.append(review_content.strip())
                time.sleep(1)
                
            except:
                rev_content.extend(['error' for x in range(n_rev)])
                time.sleep(1)
            
            
            #username review
            try:
    
                blog_lnk=driver.find_elements_by_xpath("//div[@class='reviewInfoGrp lnkExtend']/div[@class='reviewInfoBot origin']/div[@class='review_lnk']/p/a")
                links_blog=[]
                for el in blog_lnk:
                    links_blog.append(el.get_attribute('href'))
                for el in links_blog:
                    try:
                        driver.get(str(el))
                        user=driver.find_element_by_id('ImgLayer').text
                        userlist.append(user)
                    except:
                        userlist.append('error')
            
            except:
                
                userlist.append('error')

                
    time.sleep(5)
    
    
    
    
    
    
    
    
    
    

    

    
    
#ONE LINE REVIEWS:


    
    try:
        time.sleep(1)
        url= str(book) #ci riportiamo al punto giusto, a inizio pagina
        driver.get(url)
    except:
        time.sleep(5)
        driver.get(url)
        
    #numero di reviews one line
    n_rev_ol=nrev_list_ol[numero_libro]

    
        
    
    if n_rev_ol > 6: #se le ol reviews non sono solo ristrette in una pagina
    
        try:
            time.sleep(1)
            page_link_ol=driver.find_element_by_xpath("//div[@class='rvCmt_sort']/div[@class='rvCmt_sortLft']/div[@class='yesUI_pagenS']/a[@class='num']").get_attribute('href')
        except:
            time.sleep(5)
            page_link_ol=driver.find_element_by_xpath("//div[@id='infoset_oneCommentList']/div[@class='rvCmt_sort']/div[@class='rvCmt_sortLft']/div[@class='yesUI_pagenS']/a[@class='num']").get_attribute('href')
        
        
        
        if n_rev_ol//6 == n_rev_ol/6:
    
            for i in range(1,int(n_rev_ol/6 +1),1):  #6 reviews per pagina
                
                try:
                    try:
                        url3=page_link_ol[:-1]+str(i)
                        driver.get(url3)
                    except:
                        time.sleep(5)
                        url3=page_link_ol[:-1]+str(i)
                        driver.get(url3)
                except:
                    continue
                 
                try:
                    try:
                        members_rev_ol=driver.find_element_by_xpath("//div[@class='infoSetCont_wrap rvCmtRow_cont clearfix']")
                    except:
                        time.sleep(5)
                        members_rev_ol=driver.find_element_by_xpath("//div[@class='infoSetCont_wrap rvCmtRow_cont clearfix']")
                except:
                    continue

                    
                #cominciamo con il fillare la lista dei titoli, isbn e genere
                titoli_ol.extend([title[numero_libro] for x in range(6)])
                isbn_code_ol.extend([isbn[numero_libro] for x in range(6)])
                genere_ol.extend([gen[numero_libro] for x in range(6)])
        
                #data ol
                try:
                    review_date_ol=members_rev_ol.find_elements_by_class_name('txt_date')
                    for el in review_date_ol:
                        rev_date_ol.append(el.text)
                    time.sleep(1)
            
                except:
                    rev_date_ol.extend(['error' for x in range(6)])
                    time.sleep(1)
                    
                #n_likes
                
                try:
                    likes=members_rev_ol.find_elements_by_class_name('yes_b.txt')
                    for el in likes:
                        n_likes_ol.append(el.text)
                except:
                    n_likes_ol.extend(['error' for x in range(6)])
        
                #ratings ol
                try:
                    review_rating_ol = members_rev_ol.find_elements_by_class_name('cmt_rating') 
                    for el in review_rating_ol:
                        rev_ratings_ol.append(re.findall(r'\d+', el.text))
                    time.sleep(1)
                
                except:
                    rev_ratings_ol.extend(['error' for x in range(6)])
                    time.sleep(1)
            
            
                #contenuto ol
                try:
                    review_cont_ol = members_rev_ol.find_elements_by_xpath("//div[@class='cmtInfoBox']/div[@class='cmt_cont']/span[@class='txt']")
                    for el in review_cont_ol:
                        review_content_ol = el.text
                        rev_content_ol.append(review_content_ol)
                    time.sleep(1)
                
                except:
                    rev_content_ol.extend(['error' for x in range(6)])
                    time.sleep(1)
            
                #username review oneline
        
                user_ol=driver.find_elements_by_class_name('lnk_nick')
                for el in user_ol:
                    try:
                        userlist_ol.append(el.text)
                    except:
                        userlist_ol.append('error')
                        
        
        
                        
                        
        
        
        else:
            
            for i in range(1,int(n_rev_ol/6 +2),1):  #6 reviews per pagina
                
                try:
                    try:
                        url3=page_link_ol[:-1]+str(i)
                        driver.get(url3)
                    except:
                        time.sleep(5)
                        url3=page_link_ol[:-1]+str(i)
                        driver.get(url3)
                except:
                    continue
                 
                try:
                    try:
                        members_rev_ol=driver.find_element_by_xpath("//div[@class='infoSetCont_wrap rvCmtRow_cont clearfix']")
                    except:
                        time.sleep(5)
                        members_rev_ol=driver.find_element_by_xpath("//div[@class='infoSetCont_wrap rvCmtRow_cont clearfix']")
                except:
                    continue

                    
                #cominciamo con il fillare la lista dei titoli, isbn e genere
                titoli_ol.extend([title[numero_libro] for x in range(6)])
                isbn_code_ol.extend([isbn[numero_libro] for x in range(6)])
                genere_ol.extend([gen[numero_libro] for x in range(6)])
        
                #data ol
                try:
                    review_date_ol=members_rev_ol.find_elements_by_class_name('txt_date')
                    for el in review_date_ol:
                        rev_date_ol.append(el.text)
                    time.sleep(1)
            
                except:
                    rev_date_ol.extend(['error' for x in range(6)])
                    time.sleep(1)
                    
                #n_likes
                
                try:
                    likes=members_rev_ol.find_elements_by_class_name('yes_b.txt')
                    for el in likes:
                        n_likes_ol.append(el.text)
                except:
                    n_likes_ol.extend(['error' for x in range(6)])
        
                #ratings ol
                try:
                    review_rating_ol = members_rev_ol.find_elements_by_class_name('cmt_rating') 
                    for el in review_rating_ol:
                        rev_ratings_ol.append(re.findall(r'\d+', el.text))
                    time.sleep(1)
                
                except:
                    rev_ratings_ol.extend(['error' for x in range(6)])
                    time.sleep(1)
            
            
                #contenuto ol
                try:
                    review_cont_ol = members_rev_ol.find_elements_by_xpath("//div[@class='cmtInfoBox']/div[@class='cmt_cont']/span[@class='txt']")
                    for el in review_cont_ol:
                        review_content_ol = el.text
                        rev_content_ol.append(review_content_ol)
                    time.sleep(1)
                
                except:
                    rev_content_ol.extend(['error' for x in range(6)])
                    time.sleep(1)
            
                #username review oneline
        
                user_ol=driver.find_elements_by_class_name('lnk_nick')
                for el in user_ol:
                    try:
                        userlist_ol.append(el.text)
                    except:
                        userlist_ol.append('error')                      
                        
    
    
    
    else:   #se c'è solo una pagina in cui prendere i dati
            
                 
            try:
                    try:
                        members_rev_ol=driver.find_element_by_xpath("//div[@class='infoSetCont_wrap rvCmtRow_cont clearfix']")
                    except:
                        time.sleep(5)
                        members_rev_ol=driver.find_element_by_xpath("//div[@class='infoSetCont_wrap rvCmtRow_cont clearfix']")
            except:
                    continue
                    
                    
                    
            #cominciamo con il fillare la lista dei titoli, isbn e genere
            titoli_ol.extend([title[numero_libro] for x in range(n_rev_ol)])
            isbn_code_ol.extend([isbn[numero_libro] for x in range(n_rev_ol)])
            genere_ol.extend([gen[numero_libro] for x in range(n_rev_ol)])
                    
                    
            
            #data ol
            try:
                review_date_ol=members_rev_ol.find_elements_by_class_name('txt_date')
                for el in review_date_ol:
                    rev_date_ol.append(el.text)
                time.sleep(1)
            
            except:
                rev_date_ol.extend(['error' for x in range(n_rev_ol)])
                time.sleep(1)
        
            #ratings ol
            try:
                review_rating_ol = members_rev_ol.find_elements_by_class_name('cmt_rating') 
                for el in review_rating_ol:
                    rev_ratings_ol.append(re.findall(r'\d+', el.text))
                time.sleep(1)
                
            except:
                rev_ratings_ol.extend(['error' for x in range(n_rev_ol)])
                time.sleep(1)
                
            
            #n_likes
                
            try:
                    likes=members_rev_ol.find_elements_by_class_name('yes_b.txt')
                    for el in likes:
                        n_likes_ol.append(el.text)
            except:
                    n_likes_ol.extend(['error' for x in range(n_rev_ol)])
            
            
            
            #contenuto ol
            try:
                review_cont_ol = members_rev_ol.find_elements_by_xpath("//div[@class='cmtInfoBox']/div[@class='cmt_cont']/span[@class='txt']")
                for el in review_cont_ol:
                    review_content_ol = el.text
                    rev_content_ol.append(review_content_ol)
                time.sleep(1)
                
            except:
                rev_content_ol.extend(['error' for x in range(n_rev_ol)])
                time.sleep(1)
            
            
            
            #username review oneline
            
            try:
                user_ol=driver.find_elements_by_class_name('lnk_nick')
                for el in user_ol:
                    try:
                        userlist_ol.append(el.text)
                    except:
                        userlist_ol.append('error')
            except:
                userlist_ol.append('error')
                    
    
    
        

        
        
        
        
        
        
            
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
   
                    
                    
                    
    
    #uniformiamo la lunghezza delle liste titoli alla fine di ogni libro:
    titoli=titoli[:len(rev_content)]
    isbn_code=isbn_code[:len(rev_content)]
    genere=genere[:len(rev_content)]
    
    titoli_ol=titoli_ol[:len(rev_content_ol)]
    isbn_code_ol=isbn_code_ol[:len(rev_content_ol)]
    genere_ol=genere_ol[:len(rev_content_ol)]
    
    
    print(numero_libro)
    print(len(titoli))
    print(len(userlist))
    print(len(titoli_ol))
    print(len(userlist_ol))
            

            
#secondo me mancano i libri da 102 a 172
# Out:
# 102
# 7990
# 7990
# 10853
# 10853
# 103
# 8093
# 8093
# 10882
# 10882
# 104
# 8112
# 8112
# 10933
# 10933
# 105
# 8136
# 8136
# 10975
# 10975
# 106
# 8178
# 8178
# 11089
# 11089
# 107
# 8207
# 8207
# 11143
# 11143
# 108
# 8296
# 8296
# 11153
# 11153
# 109
# 8351
# 8351
# 11220
# 11220
# 110
# 8398
# 8398
# 11269
# 11269
# 111
# 8471
# 8471
# 11323
# 11323
# 112
# 8530
# 8530
# 11910
# 11910
# 113
# 8560
# 8560
# 11936
# 11936
# 114
# 8596
# 8596
# 11946
# 11946
# 115
# 8621
# 8621
# 11970
# 11970
# 116
# 8706
# 8706
# 12194
# 12194
# 117
# 8721
# 8721
# 12208
# 12208
# 118
# 8795
# 8795
# 12388
# 12388
# 119
# 8831
# 8831
# 12448
# 12448
# 120
# 8842
# 8842
# 12462
# 12462
# 121
# 8880
# 8880
# 12499
# 12499
# 122
# 8911
# 8911
# 12513
# 12513
# 123
# 8953
# 8953
# 12545
# 12545
# 124
# 8980
# 8980
# 12573
# 12573
# 125
# 9012
# 9012
# 12609
# 12609
# 126
# 9064
# 9064
# 12846
# 12846
# 127
# 9131
# 9131
# 12870
# 12870
# 128
# 9182
# 9182
# 12889
# 12889
# 129
# 9233
# 9233
# 12896
# 12896
# 130
# 9264
# 9264
# 13060
# 13060
# 131
# 9286
# 9286
# 13103
# 13103
# 132
# 9328
# 9328
# 13111
# 13111
# 133
# 9403
# 9403
# 13291
# 13291
# 134
# 9468
# 9468
# 13302
# 13302
# 135
# 9488
# 9488
# 13351
# 13351
# 136
# 9508
# 9508
# 13383
# 13383
# 137
# 9550
# 9550
# 13415
# 13415
# 138
# 9590
# 9590
# 13467
# 13467
# 139
# 9632
# 9632
# 13495
# 13495
# 140
# 9685
# 9685
# 13527
# 13527
# 141
# 9715
# 9715
# 13539
# 13539
# 142
# 9732
# 9732
# 13633
# 13633
# 143
# 9758
# 9758
# 13691
# 13691
# 144
# 9782
# 9782
# 13704
# 13704
# 145
# 9807
# 9807
# 13722
# 13722
# 146
# 9841
# 9841
# 13744
# 13744
# 147
# 9929
# 9929
# 13941
# 13941
# 148
# 9942
# 9942
# 13990
# 13990
# 149
# 9970
# 9970
# 14011
# 14011
# 150
# 10015
# 10015
# 14034
# 14034
# 151
# 10050
# 10050
# 14120
# 14120
# 152
# 10116
# 10116
# 14182
# 14182
# 153
# 10161
# 10161
# 14192
# 14192
# 154
# 10218
# 10218
# 14236
# 14236
# 155
# 10249
# 10249
# 14283
# 14283
# 156
# 10342
# 10342
# 14318
# 14318
# 157
# 10384
# 10384
# 14333
# 14333
# 158
# 10442
# 10442
# 14342
# 14342
# 159
# 10512
# 10512
# 14393
# 14393
# 160
# 10555
# 10555
# 14443
# 14443
# 161
# 10582
# 10582
# 14468
# 14468
# 162
# 10632
# 10632
# 14501
# 14501
# 163
# 10661
# 10661
# 14511
# 14511
# 164
# 10752
# 10752
# 14706
# 14706
# 165
# 10812
# 10812
# 14746
# 14746
# 166
# 10864
# 10864
# 14756
# 14756
# 167
# 10920
# 10920
# 14770
# 14770
# 168
# 10999
# 10999
# 14961
# 14961
# 169
# 11041
# 11041
# 15015
# 15015
# 170
# 11071
# 11071
# 15028
# 15028
# 171
# 11101
# 11101
# 15072
# 15072
# 172
# 11131
# 11131
# 15114
# 15114

# %%
print(len(rev_content))
print(len(titoli))
print(len(genere))
print(len(rev_ratings))
print(len(rev_date))
print(len(isbn_code))
print(len(userlist))
print(len(n_likes))
# Out:
# 11131
# 11131
# 11131
# 11131
# 11131
# 11131
# 11131
# 11131

# %%
print(len(rev_content_ol))
print(len(genere_ol))
print(len(rev_ratings_ol))
print(len(rev_date_ol))
print(len(titoli_ol))
print(len(userlist_ol))
print(len(isbn_code_ol))
print(len(n_likes_ol))
# Out:
# 15114
# 15114
# 15114
# 15114
# 15114
# 15114
# 15114
# 15114

# %%
#REVIEWS LUNGHE

reviews=pd.DataFrame(list(zip(genere,titoli,isbn_code,userlist,rev_date,rev_ratings,n_likes,rev_content)), columns=['Genere','Title','ISBN','Username','Review_Date','Review_Ratings','Num_Likes','Review_Content'])
reviews=reviews.reset_index()
#affil_covid_def=affil_covid_def.drop('index',axis=1)
reviews
# Out:
#        index        Genere      Title           ISBN  Username Review_Date  \
# 0          0  Children_Lit  푸른 사자 와니니  9788936442804       자목련  2021-10-13
# 1          1  Children_Lit  푸른 사자 와니니  9788936442804   koj1321  2021-08-03
# 2          2  Children_Lit  푸른 사자 와니니  9788936442804     빨강머리앤  2021-05-25
# 3          3  Children_Lit  푸른 사자 와니니  9788936442804  basara10  2021-05-22
# 4          4  Children_Lit  푸른 사자 와니니  9788936442804  choi5020  2021-05-11
# ...      ...           ...        ...            ...       ...         ...
# 11126  11126  Children_Lit     코드네임 I  9788952789938      dub2  2019-10-22
# 11127  11127  Children_Lit     코드네임 I  9788952789938  cipher76  2019-10-22
# 11128  11128  Children_Lit     코드네임 I  9788952789938       율윤맘  2019-10-17
# 11129  11129  Children_Lit     코드네임 I  9788952789938     서은현준맘  2019-10-06
# 11130  11130  Children_Lit     코드네임 I  9788952789938  young114  2019-10-04
#
#       Review_Ratings Num_Likes  \
# 0             [4, 4]         3
# 1             [5, 5]         0
# 2             [4, 4]         0
# 3             [5, 4]         0
# 4             [5, 5]         0
# ...              ...       ...
# 11126         [5, 5]         0
# 11127         [5, 5]         0
# 11128         [5, 5]         0
# 11129         [5, 5]         0
# 11130         [5, 5]         0
#
#                                           Review_Content
# 0      종종 동물의 왕국이란 프로그램을 시청한다. 어렸을 때에는 약육강식의 피라미드로 인식...
# 1      워낙 서점 등에서 어린이 도서 분야 상위 랭크를 차지하고 있는데\n\n워낙 라이언 ...
# 2      학교에서 하는 한학기에 1권씩 정해서 하는 독서활동인\n\n온책읽기 지정 도서라 구...
# 3      푸른 사자 와니니이현항상 아이를 핑계로 아동도서를 구매하지만 사실은 내가 읽고 싶어...
# 4      우리 아이가 푸른사자 와니니를 좋아해서 읽어보고싶다하여 주문하게 되었습니다.코로나라...
# ...                                                  ...
# 11126  누구냐 넌!! 항상 호기심을 불러일으키는 특별한 인물의 등장을 예고하는책 커버 표지...
# 11127  볼로냐 라가치 상 수상작가 '강경수' 작가의 야심작, 코드네임 시리즈.벌써 X, K...
# 11128  초등 아이들 사이에서 인기있는 첩보물 코드네임 시리즈는 익히 들어 알고는 있었는데요...
# 11129  아이들이 너무나도 좋아하는 코드네임 시리즈~!!볼때마다 강경수 작가님을 사랑하지 않...
# 11130  진짜 매번 새롭게 기대되는 내용이예요! (물론 그림체는 말 할 것도 없이 기대돼요!...
#
# [11131 rows x 9 columns]

# %%
reviews[reviews['Review_Content']=='error']
# Out:
# Empty DataFrame
# Columns: [index, Genere, Title, ISBN, Username, Review_Date, Review_Ratings, Num_Likes, Review_Content]
# Index: []

# %%
#REVIEWS ONELINE

reviews_ol=pd.DataFrame(list(zip(genere_ol,titoli_ol,isbn_code_ol,userlist_ol,rev_date_ol,rev_ratings_ol,n_likes_ol,rev_content_ol)), columns=['Genere','Title','ISBN','Username_ol','Review_Date_ol','Review_Ratings_ol','Num_Likes_ol','Review_Content_ol'])
reviews_ol=reviews_ol.reset_index()
#affil_covid_def=affil_covid_def.drop('index',axis=1)
reviews_ol
# Out:
#        index        Genere      Title           ISBN Username_ol  \
# 0          0  Children_Lit  푸른 사자 와니니  9788936442804       새***작
# 1          1  Children_Lit  푸른 사자 와니니  9788936442804       i***a
# 2          2  Children_Lit  푸른 사자 와니니  9788936442804   n*******6
# 3          3  Children_Lit  푸른 사자 와니니  9788936442804          행*
# 4          4  Children_Lit  푸른 사자 와니니  9788936442804       호***뜨
# ...      ...           ...        ...            ...         ...
# 15109  15109  Children_Lit     코드네임 I  9788952789938         또*이
# 15110  15110  Children_Lit     코드네임 I  9788952789938    c******l
# 15111  15111  Children_Lit     코드네임 I  9788952789938    m******5
# 15112  15112  Children_Lit     코드네임 I  9788952789938        붕**숙
# 15113  15113  Children_Lit     코드네임 I  9788952789938    l******0
#
#       Review_Date_ol Review_Ratings_ol Num_Likes_ol  \
# 0         2021-10-11               [4]            0
# 1         2021-10-06               [5]            0
# 2         2021-09-30               [5]            0
# 3         2021-09-29               [4]            0
# 4         2021-09-26               [5]            0
# ...              ...               ...          ...
# 15109     2019-10-21               [5]            0
# 15110     2019-10-12               [5]            0
# 15111     2019-10-05               [5]            0
# 15112     2019-10-04               [5]            0
# 15113     2019-09-27               [5]            0
#
#                                 Review_Content_ol
# 0                                      이야기가 재밌네요.
# 1                                  초5학년 재밌게 읽었습니다
# 2                                  아이가 재미있게 읽었어요.
# 3                                        어린이 추천도서
# 4                                   학교 온읽기 책으로 구입
# ...                                           ...
# 15109                         코드네임 시리스는 무조건 잼있다네요
# 15110                       코드네임 시리즈중에서도 잼있다고 하네요
# 15111  몇달동안 기다려서 산거라 더 재미있게 느껴지네요! 스토리도 개그도 탄탄해요!
# 15112                              아들이 많이 기다렸어요^^
# 15113                            아이가 너무 좋아하는 책입니다
#
# [15114 rows x 9 columns]

# %%
reviews_ol[reviews_ol['Review_Content_ol']=='error']
# Out:
# Empty DataFrame
# Columns: [index, Genere, Title, ISBN, Username_ol, Review_Date_ol, Review_Ratings_ol, Num_Likes_ol, Review_Content_ol]
# Index: []

# %%
#numero di recensioni = numero di voti

# %%
not_found #non ci sono libri non trovati
# Out:
# []

# %%
#numero di recensioni = numero di voti

#controllo duplicati
reviews2=reviews.drop_duplicates( subset=['Title','ISBN','Username','Review_Content'],keep='first',inplace=False)
reviews2 #amzon ita filtrato dalle righe duplicate
# Out:
#        index        Genere      Title           ISBN  Username Review_Date  \
# 0          0  Children_Lit  푸른 사자 와니니  9788936442804       자목련  2021-10-13
# 1          1  Children_Lit  푸른 사자 와니니  9788936442804   koj1321  2021-08-03
# 2          2  Children_Lit  푸른 사자 와니니  9788936442804     빨강머리앤  2021-05-25
# 3          3  Children_Lit  푸른 사자 와니니  9788936442804  basara10  2021-05-22
# 4          4  Children_Lit  푸른 사자 와니니  9788936442804  choi5020  2021-05-11
# ...      ...           ...        ...            ...       ...         ...
# 11126  11126  Children_Lit     코드네임 I  9788952789938      dub2  2019-10-22
# 11127  11127  Children_Lit     코드네임 I  9788952789938  cipher76  2019-10-22
# 11128  11128  Children_Lit     코드네임 I  9788952789938       율윤맘  2019-10-17
# 11129  11129  Children_Lit     코드네임 I  9788952789938     서은현준맘  2019-10-06
# 11130  11130  Children_Lit     코드네임 I  9788952789938  young114  2019-10-04
#
#       Review_Ratings Num_Likes  \
# 0             [4, 4]         3
# 1             [5, 5]         0
# 2             [4, 4]         0
# 3             [5, 4]         0
# 4             [5, 5]         0
# ...              ...       ...
# 11126         [5, 5]         0
# 11127         [5, 5]         0
# 11128         [5, 5]         0
# 11129         [5, 5]         0
# 11130         [5, 5]         0
#
#                                           Review_Content
# 0      종종 동물의 왕국이란 프로그램을 시청한다. 어렸을 때에는 약육강식의 피라미드로 인식...
# 1      워낙 서점 등에서 어린이 도서 분야 상위 랭크를 차지하고 있는데\n\n워낙 라이언 ...
# 2      학교에서 하는 한학기에 1권씩 정해서 하는 독서활동인\n\n온책읽기 지정 도서라 구...
# 3      푸른 사자 와니니이현항상 아이를 핑계로 아동도서를 구매하지만 사실은 내가 읽고 싶어...
# 4      우리 아이가 푸른사자 와니니를 좋아해서 읽어보고싶다하여 주문하게 되었습니다.코로나라...
# ...                                                  ...
# 11126  누구냐 넌!! 항상 호기심을 불러일으키는 특별한 인물의 등장을 예고하는책 커버 표지...
# 11127  볼로냐 라가치 상 수상작가 '강경수' 작가의 야심작, 코드네임 시리즈.벌써 X, K...
# 11128  초등 아이들 사이에서 인기있는 첩보물 코드네임 시리즈는 익히 들어 알고는 있었는데요...
# 11129  아이들이 너무나도 좋아하는 코드네임 시리즈~!!볼때마다 강경수 작가님을 사랑하지 않...
# 11130  진짜 매번 새롭게 기대되는 내용이예요! (물론 그림체는 말 할 것도 없이 기대돼요!...
#
# [11064 rows x 9 columns]

# %%
#controllo duplicati
reviews_ol2=reviews_ol.drop_duplicates( subset=['Title','ISBN','Username_ol','Review_Content_ol'],keep='first',inplace=False)
reviews_ol2 #amzon ita filtrato dalle righe duplicate
# Out:
#        index        Genere      Title           ISBN Username_ol  \
# 0          0  Children_Lit  푸른 사자 와니니  9788936442804       새***작
# 1          1  Children_Lit  푸른 사자 와니니  9788936442804       i***a
# 2          2  Children_Lit  푸른 사자 와니니  9788936442804   n*******6
# 3          3  Children_Lit  푸른 사자 와니니  9788936442804          행*
# 4          4  Children_Lit  푸른 사자 와니니  9788936442804       호***뜨
# ...      ...           ...        ...            ...         ...
# 15109  15109  Children_Lit     코드네임 I  9788952789938         또*이
# 15110  15110  Children_Lit     코드네임 I  9788952789938    c******l
# 15111  15111  Children_Lit     코드네임 I  9788952789938    m******5
# 15112  15112  Children_Lit     코드네임 I  9788952789938        붕**숙
# 15113  15113  Children_Lit     코드네임 I  9788952789938    l******0
#
#       Review_Date_ol Review_Ratings_ol Num_Likes_ol  \
# 0         2021-10-11               [4]            0
# 1         2021-10-06               [5]            0
# 2         2021-09-30               [5]            0
# 3         2021-09-29               [4]            0
# 4         2021-09-26               [5]            0
# ...              ...               ...          ...
# 15109     2019-10-21               [5]            0
# 15110     2019-10-12               [5]            0
# 15111     2019-10-05               [5]            0
# 15112     2019-10-04               [5]            0
# 15113     2019-09-27               [5]            0
#
#                                 Review_Content_ol
# 0                                      이야기가 재밌네요.
# 1                                  초5학년 재밌게 읽었습니다
# 2                                  아이가 재미있게 읽었어요.
# 3                                        어린이 추천도서
# 4                                   학교 온읽기 책으로 구입
# ...                                           ...
# 15109                         코드네임 시리스는 무조건 잼있다네요
# 15110                       코드네임 시리즈중에서도 잼있다고 하네요
# 15111  몇달동안 기다려서 산거라 더 재미있게 느껴지네요! 스토리도 개그도 탄탄해요!
# 15112                              아들이 많이 기다렸어요^^
# 15113                            아이가 너무 좋아하는 책입니다
#
# [14982 rows x 9 columns]

# %%
reviews2=reviews2.reset_index()
reviews_ol2=reviews_ol2.reset_index()

# %%
#selezione lingua corretta
from langdetect import detect
lang=[]
for index, row in reviews2['Review_Content'].iteritems():
    try:
        language = detect(row) #detecting each row
        lang.append(language)
    except:
        lang.append('not found')
print(lang[:10])

ind=[]
count=0
for el in lang:
    if el != 'ko':
        ind.append(count)
    count+=1
print(ind)
# Out:
# ['ko', 'ko', 'ko', 'ko', 'ko', 'ko', 'ko', 'ko', 'ko', 'ko']
# [791, 1388, 2007, 4300, 4617, 4806, 5344, 5662, 5665, 6312, 7825, 8511, 8514, 8521, 9046, 9256, 9595, 10357, 10546]

# %%
r=reviews2['Review_Content'].to_list()
r[2007]
# Out:
# ''

# %%
#valuta se mandarlo
reviews3=reviews2.drop(ind,axis=0).drop('level_0',axis=1).reset_index()
reviews3
# Out:
#        level_0  index        Genere      Title           ISBN  Username  \
# 0            0      0  Children_Lit  푸른 사자 와니니  9788936442804       자목련
# 1            1      1  Children_Lit  푸른 사자 와니니  9788936442804   koj1321
# 2            2      2  Children_Lit  푸른 사자 와니니  9788936442804     빨강머리앤
# 3            3      3  Children_Lit  푸른 사자 와니니  9788936442804  basara10
# 4            4      4  Children_Lit  푸른 사자 와니니  9788936442804  choi5020
# ...        ...    ...           ...        ...            ...       ...
# 11040    11059  11126  Children_Lit     코드네임 I  9788952789938      dub2
# 11041    11060  11127  Children_Lit     코드네임 I  9788952789938  cipher76
# 11042    11061  11128  Children_Lit     코드네임 I  9788952789938       율윤맘
# 11043    11062  11129  Children_Lit     코드네임 I  9788952789938     서은현준맘
# 11044    11063  11130  Children_Lit     코드네임 I  9788952789938  young114
#
#       Review_Date Review_Ratings Num_Likes  \
# 0      2021-10-13         [4, 4]         3
# 1      2021-08-03         [5, 5]         0
# 2      2021-05-25         [4, 4]         0
# 3      2021-05-22         [5, 4]         0
# 4      2021-05-11         [5, 5]         0
# ...           ...            ...       ...
# 11040  2019-10-22         [5, 5]         0
# 11041  2019-10-22         [5, 5]         0
# 11042  2019-10-17         [5, 5]         0
# 11043  2019-10-06         [5, 5]         0
# 11044  2019-10-04         [5, 5]         0
#
#                                           Review_Content
# 0      종종 동물의 왕국이란 프로그램을 시청한다. 어렸을 때에는 약육강식의 피라미드로 인식...
# 1      워낙 서점 등에서 어린이 도서 분야 상위 랭크를 차지하고 있는데\n\n워낙 라이언 ...
# 2      학교에서 하는 한학기에 1권씩 정해서 하는 독서활동인\n\n온책읽기 지정 도서라 구...
# 3      푸른 사자 와니니이현항상 아이를 핑계로 아동도서를 구매하지만 사실은 내가 읽고 싶어...
# 4      우리 아이가 푸른사자 와니니를 좋아해서 읽어보고싶다하여 주문하게 되었습니다.코로나라...
# ...                                                  ...
# 11040  누구냐 넌!! 항상 호기심을 불러일으키는 특별한 인물의 등장을 예고하는책 커버 표지...
# 11041  볼로냐 라가치 상 수상작가 '강경수' 작가의 야심작, 코드네임 시리즈.벌써 X, K...
# 11042  초등 아이들 사이에서 인기있는 첩보물 코드네임 시리즈는 익히 들어 알고는 있었는데요...
# 11043  아이들이 너무나도 좋아하는 코드네임 시리즈~!!볼때마다 강경수 작가님을 사랑하지 않...
# 11044  진짜 매번 새롭게 기대되는 내용이예요! (물론 그림체는 말 할 것도 없이 기대돼요!...
#
# [11045 rows x 10 columns]

# %%
#selezione lingua corretta
from langdetect import detect
lang=[]
for index, row in reviews_ol2['Review_Content_ol'].iteritems():
    try:
        language = detect(row) #detecting each row
        lang.append(language)
    except:
        lang.append('not found')
print(lang[:10])

ind=[]
count=0
for el in lang:
    if el != 'ko':
        ind.append(count)
    count+=1
print(ind[:3])

#reviews_ol2['Review_Content_ol'][6776]  

reviews_ol3=reviews_ol2.drop(ind,axis=0).drop('level_0',axis=1).reset_index()
reviews_ol3
# Out:
# ['ko', 'ko', 'ko', 'ko', 'ko', 'ko', 'ko', 'ko', 'ko', 'ko']
# [87, 338, 549]
#        level_0  index        Genere      Title           ISBN Username_ol  \
# 0            0      0  Children_Lit  푸른 사자 와니니  9788936442804       새***작
# 1            1      1  Children_Lit  푸른 사자 와니니  9788936442804       i***a
# 2            2      2  Children_Lit  푸른 사자 와니니  9788936442804   n*******6
# 3            3      3  Children_Lit  푸른 사자 와니니  9788936442804          행*
# 4            4      4  Children_Lit  푸른 사자 와니니  9788936442804       호***뜨
# ...        ...    ...           ...        ...            ...         ...
# 14883    14977  15109  Children_Lit     코드네임 I  9788952789938         또*이
# 14884    14978  15110  Children_Lit     코드네임 I  9788952789938    c******l
# 14885    14979  15111  Children_Lit     코드네임 I  9788952789938    m******5
# 14886    14980  15112  Children_Lit     코드네임 I  9788952789938        붕**숙
# 14887    14981  15113  Children_Lit     코드네임 I  9788952789938    l******0
#
#       Review_Date_ol Review_Ratings_ol Num_Likes_ol  \
# 0         2021-10-11               [4]            0
# 1         2021-10-06               [5]            0
# 2         2021-09-30               [5]            0
# 3         2021-09-29               [4]            0
# 4         2021-09-26               [5]            0
# ...              ...               ...          ...
# 14883     2019-10-21               [5]            0
# 14884     2019-10-12               [5]            0
# 14885     2019-10-05               [5]            0
# 14886     2019-10-04               [5]            0
# 14887     2019-09-27               [5]            0
#
#                                 Review_Content_ol
# 0                                      이야기가 재밌네요.
# 1                                  초5학년 재밌게 읽었습니다
# 2                                  아이가 재미있게 읽었어요.
# 3                                        어린이 추천도서
# 4                                   학교 온읽기 책으로 구입
# ...                                           ...
# 14883                         코드네임 시리스는 무조건 잼있다네요
# 14884                       코드네임 시리즈중에서도 잼있다고 하네요
# 14885  몇달동안 기다려서 산거라 더 재미있게 느껴지네요! 스토리도 개그도 탄탄해요!
# 14886                              아들이 많이 기다렸어요^^
# 14887                            아이가 너무 좋아하는 책입니다
#
# [14888 rows x 10 columns]

# %%
#export file

reviews3.to_csv('Yes24_0_200.csv')
reviews_ol3.to_csv('Yes24_ol_0_200.csv')
