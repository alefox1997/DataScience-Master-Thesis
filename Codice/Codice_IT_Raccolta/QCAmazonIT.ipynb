# %%
import re
import time
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
PATH='C:\\Users\\aless\\OneDrive\\Desktop\\Laurea_magistrale\\Tesi\\chromedriver.exe'
driver = webdriver.Chrome(PATH)

# %%
#prima di tutto creiamo la lista contente tutti i link utili per lo scraping

# %%
#SE RACCOGLI PER LINK DEL GOOGLE SHEET, USA QUESTO CODICE PER CREARE LISTA LINK

#RACCOLTA LIBRI DA LINK ALTERNATIVA A RACCOLTA ISBN


lista_lnk=[]

#prendiamo tutti i link dei libri per questo genere (400) 
#children literature italiano



url= "https://www.amazon.it/s?i=stripbooks&bbn=508715031&rh=n%3A411663031%2Cn%3A508715031%2Cn%3A508720031%2Cp_6%3AA1IZZI10GE0KEI&dc&qid=1627593394&rnid=508715031&ref=sr_nr_n_15"
driver.get(url)  

page_lnk=driver.find_element_by_xpath("//ul[@class='a-pagination']/li[@class='a-normal']/a").get_attribute('href')
p1=page_lnk[0:131]
p2=page_lnk[132:-1]


for i in range(1,26,1):
    link=p1+str(i)+p2+str(i)
    url_page=str(link)
    driver.get(url_page)
    
    page_links=driver.find_elements_by_xpath("//a[@class='a-link-normal s-no-outline']")
    for el in page_links:
        lista_lnk.append(el.get_attribute('href'))
        
print(len(lista_lnk))




#prendiamo tutti i link dei libri per questo genere (200) 
#romance italiano


url= "https://www.amazon.it/s?i=stripbooks&bbn=411664031&rh=n%3A411663031%2Cn%3A508775031%2Cp_6%3AA1IZZI10GE0KEI&dc&qid=1627593624&rnid=411664031&ref=sr_nr_n_23"
driver.get(url)  

page_lnk=driver.find_element_by_xpath("//ul[@class='a-pagination']/li[@class='a-normal']/a").get_attribute('href')
p1=page_lnk[0:115]
p2=page_lnk[116:-1]
link=p1+str(1)+p2+str(1)

for i in range(1,26,1):
    link=p1+str(i)+p2+str(i)
    url_page=str(link)
    driver.get(url_page)
    
    page_links=driver.find_elements_by_xpath("//a[@class='a-link-normal s-no-outline']")
    for el in page_links:
        lista_lnk.append(el.get_attribute('href'))
        
print(len(lista_lnk))





#prendiamo tutti i link dei libri per questo genere (400) 
#fantasy italiano 


page_lnk='https://www.amazon.it/s?i=stripbooks&bbn=1345828031&rh=n%3A411663031%2Cn%3A1345828031%2Cn%3A508772031%2Cp_6%3AA1IZZI10GE0KEI&dc&page=2&qid=1632905495&rnid=1345828031&ref=sr_pg_2'
p1=page_lnk[0:133]
p2=page_lnk[134:-1]
link=p1+str(1)+p2+str(1)

for i in range(1,26,1):
    link=p1+str(i)+p2+str(i)
    url_page=str(link)
    driver.get(url_page)
    
    page_links=driver.find_elements_by_xpath("//a[@class='a-link-normal s-no-outline']")
    for el in page_links:
        lista_lnk.append(el.get_attribute('href'))
        
print(len(lista_lnk))




#scifi italiano


page_lnk='https://www.amazon.it/s?i=stripbooks&bbn=1345828031&rh=n%3A411663031%2Cn%3A1345828031%2Cn%3A508773031%2Cp_6%3AA1IZZI10GE0KEI&dc&page=2&qid=1632903956&rnid=1345828031&ref=sr_pg_2'
p1=page_lnk[0:133]
p2=page_lnk[134:-1]
link=p1+str(1)+p2+str(1)

for i in range(1,26,1):
    link=p1+str(i)+p2+str(i)
    url_page=str(link)
    driver.get(url_page)
    
    page_links=driver.find_elements_by_xpath("//a[@class='a-link-normal s-no-outline']")
    for el in page_links:
        lista_lnk.append(el.get_attribute('href'))
        
print(len(lista_lnk))







#prendiamo tutti i link dei libri per questo genere (400) 
#gialli/thriller italiano


url= "https://www.amazon.it/s?i=stripbooks&bbn=411664031&rh=n%3A411663031%2Cn%3A508771031%2Cp_6%3AA1IZZI10GE0KEI&dc&qid=1627593565&rnid=411664031&ref=sr_nr_n_12"
driver.get(url)  

page_lnk=driver.find_element_by_xpath("//ul[@class='a-pagination']/li[@class='a-normal']/a").get_attribute('href')
p1=page_lnk[0:115]
p2=page_lnk[116:-1]
link=p1+str(1)+p2+str(1)

for i in range(1,26,1):
    link=p1+str(i)+p2+str(i)
    url_page=str(link)
    driver.get(url_page)
    
    page_links=driver.find_elements_by_xpath("//a[@class='a-link-normal s-no-outline']")
    for el in page_links:
        lista_lnk.append(el.get_attribute('href'))
        
print(len(lista_lnk))
# Out:
# 400
# 800
# 1200
# 1600
# 2000

# %%
from itertools import repeat
gen=[]
gen.extend(repeat('Children_Lit',400))
gen.extend(repeat('Romance',400))
gen.extend(repeat('Fantasy',400))
gen.extend(repeat('Scifi',400))
gen.extend(repeat('Thriller',400))
#gen

# %%
gen_lnk=pd.DataFrame(list(zip(lista_lnk,gen)),columns=['Link','Genre'])
gen_lnk
# Out:
#                                                    Link         Genre
# 0     https://www.amazon.it/portale-magico-Ninna-Mat...  Children_Lit
# 1     https://www.amazon.it/questo-Giovanni-racconto...  Children_Lit
# 2     https://www.amazon.it/mostro-Fossilonia-Vastat...  Children_Lit
# 3     https://www.amazon.it/Harry-Potter-pietra-filo...  Children_Lit
# 4     https://www.amazon.it/Dieci-piccoli-indiani-Ag...  Children_Lit
# ...                                                 ...           ...
# 1995  https://www.amazon.it/Good-Girl-Blood-Holly-Ja...      Thriller
# 1996  https://www.amazon.it/Tempesta-profumo-mandorl...      Thriller
# 1997  https://www.amazon.it/ragazza-che-guardava-lac...      Thriller
# 1998  https://www.amazon.it/Cronache-selvaggio-West-...      Thriller
# 1999  https://www.amazon.it/valore-affettivo-Nicolet...      Thriller
#
# [2000 rows x 2 columns]

# %%
#filtriamo eventuali libri duplicati dal dataframe
indici=[]
count=0
for el in lista_lnk:
    lin=0
    for link in lista_lnk:
        if el == link and count!=lin:
            indici.append(count)
        lin+=1
    count+=1
    
ind=[]
for el in indici:
    if el not in ind:
        ind.append(el)
        
print(len(indici))
print(len(ind))
# Out:
# 0
# 0

# %%
#non otteniamo duplicati a differenza di goodreads per inglese. le categorie sembrano essere ben distinte

# %%
title=[]
author=[]
isbn_code=[]
n_pages=[]
avg_rat=[]
distr_rating=[]
n_voti=[]
n_review=[]
pub_date=[]
lingua=[]

#genere suggerito lo prendiamo da anobii per disambiguare

# %%
for link in lista_lnk:
    time.sleep(1)
    try:
        try:
            driver.get(link)
        except:
            time.sleep(5)
            driver.get(link)
    except:
        title.append('error')
        author.append('error')
        isbn_code.append('error')
        n_pages.append('error')
        avg_rat.append('error')
        distr_rating.append('error')
        n_voti.append('error')
        n_review.append('error')
        pub_date.append('error')
        
    
    #titolo
    try:
        titolo = driver.find_element_by_xpath("//div[@class='a-section a-spacing-none']/h1[@id='title']/span[@id='productTitle']")
        title.append(titolo.text)
    except:
        title.append('error')
    
    #autore
    try:
        autore = driver.find_element_by_xpath("//span[@class='author notFaded']")
        author.append(autore.text)
    except:
        author.append('error')
    
    #isbn
    try:
        time.sleep(1)
        isbn = driver.find_elements_by_xpath("//ul[@class='a-unordered-list a-nostyle a-vertical a-spacing-none detail-bullet-list']/li/span[@class='a-list-item']")
        code = isbn[4].get_attribute('textContent')
        isbn_code.append(code[16:30])
    except:
        isbn_code.append('error')
        
    
    #data pubb
    try:
        date = isbn[0].get_attribute('textContent')
        pub_date.append(date)
    except:
        pub_date.append('error')
        
    
    #lingua
    try:
        lang = isbn[1].get_attribute('textContent')
        lingua.append(lang)
    except:
        lingua.append('error')
    
    
    #numero pagine
    try:
        try:
            pages = isbn[2].get_attribute('textContent')
            p=re.findall(r'\d+', pages)
            n_pages.append(p[0])
        
        except IndexError:  #capita che ci sia un codiice ASIN che sballa le cose
            pages = isbn[3].get_attribute('textContent')
            p=re.findall(r'\d+', pages)
            n_pages.append(p[0])
    except:
        n_pages.append('error')
    
   
    #stars
    try:
        stars = driver.find_element_by_xpath("//div[@id='reviewsMedley']/div[@class='a-fixed-left-grid-inner']/div[@class='a-fixed-left-grid-col a-col-left']/div[@class='a-section a-spacing-none a-spacing-top-mini cr-widget-ACR']/div[@class='a-fixed-left-grid AverageCustomerReviews a-spacing-small']/div[@class='a-fixed-left-grid-inner']/div[@class='a-fixed-left-grid-col a-col-left']/i[@data-hook='average-star-rating']/span[@class='a-icon-alt']")
        stars = stars.get_attribute('textContent')
        avg_rat.append(float(stars[0:3].replace(',','.')))
    except:
        avg_rat.append('error')
    
    
    #distributed rating
    try:
        dist_rat = driver.find_element_by_xpath("//div[@id='reviewsMedley']/div[@class='a-fixed-left-grid-inner']/div[@class='a-fixed-left-grid-col a-col-left']/span[@class='cr-widget-Histogram']")
        dist_rat = dist_rat.get_attribute('textContent')
        distr_rating.append(re.findall(r'\d+\%' ,dist_rat))
    except:
        distr_rating.append('error')


    
    #numero voti e recensioni 
    try:
        time.sleep(1)
        all_rev=driver.find_element_by_xpath("//a[@data-hook='see-all-reviews-link-foot']")
        n_rev_link=all_rev.get_attribute('href')
        url2=str(n_rev_link)
        driver.get(url2)
        n_rev=driver.find_element_by_xpath("//div[@data-hook='cr-filter-info-review-rating-count']/span")
        v_r=n_rev.text.split('|')
        count=0
        for el in v_r:
            el=el.replace('.','')
            if count==0:
                n_voti.append(float(re.findall(r'\d+' ,el)[0]))
                count+=1
            else:
                n_review.append(float(re.findall(r'\d+' ,el)[0]))
    except:
        n_voti.append('error')
        n_review.append('error')

# %%
print(len(gen))
print(len(title))
print(len(author))
print(len(isbn_code))
print(len(n_pages))
print(len(avg_rat))
print(len(distr_rating))
print(len(n_voti))
print(len(n_review))
print(len(pub_date))
print(len(lingua))
# Out:
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000

# %%
#filtri applicabili al dataset: distr rating scombinato , errori sull'isbn

# %%
#vediamo quali isbn hanno lunghezza diversa da quella predefinita
er_isbn=[]  #cerchiamo gli indici degli isbn da eliminare una volta creato il dataset
x=0
for el in isbn_code:
    if len(str(el))!= 14:
        er_isbn.append(x)
    x+=1
print(len(er_isbn))
#er_isbn
# Out:
# 33

# %%
#controllo distr rating
dr=0
ids=[]
for el in distr_rating:
    if len(el)!=5:
        ids.append(dr)
    dr+=1
print(len(ids))
#ids
# Out:
# 632

# %%
#uniamo le liste ed ordiniamo:
for el in er_isbn:
    if el not in ids:
        ids.append(el)
ids.sort(reverse=False)
print(len(ids))
ids[:10]
# Out:
# 655
# [0, 2, 8, 12, 15, 18, 21, 30, 31, 38]

# %%
#creazione dataframe

amazon_ita=pd.DataFrame(list(zip(gen,title,author,isbn_code,n_pages,pub_date,lingua,avg_rat,distr_rating,n_voti,n_review,lista_lnk)), columns=['Genere','Title','Author','ISBN','Num_Pages_AZ','Pub_Date_AZ','Lingua_AZ','Avg_Rat_AZ','Distr_Rat_AZ','N_Votes_AZ','N_Reviews_AZ','Link_AZ'])
#amazon_ita=amazon_ita.reset_index()
#affil_covid_def=affil_covid_def.drop('index',axis=1)
amazon_ita
# Out:
#             Genere                                              Title  \
# 0     Children_Lit                                  Il portale magico
# 1     Children_Lit  Per questo mi chiamo Giovanni. Da un padre a u...
# 2     Children_Lit  Il mostro di Fossilonia. Arex & Vastatore, din...
# 3     Children_Lit  Harry Potter e la pietra filosofale Tascabile ...
# 4     Children_Lit                Dieci piccoli indiani. Oscar Junior
# ...            ...                                                ...
# 1995      Thriller  Good Girl, Bad Blood: The Sunday Times Bestsel...
# 1996      Thriller             Tempesta di neve e profumo di mandorle
# 1997      Thriller                    La ragazza che guardava l'acqua
# 1998      Thriller  Cronache dal selvaggio West. Hap e Leonard, le...
# 1999      Thriller                                Il valore affettivo
#
#                           Author             ISBN Num_Pages_AZ  \
# ...

# %%
#droppiamo le righe che hanno dei problemi

amazon_ita2=amazon_ita.drop(ids,axis=0)
amazon_ita2=amazon_ita2.reset_index()
amazon_ita2
# Out:
#       index        Genere                                              Title  \
# 0         1  Children_Lit  Per questo mi chiamo Giovanni. Da un padre a u...
# 1         3  Children_Lit  Harry Potter e la pietra filosofale Tascabile ...
# 2         4  Children_Lit                Dieci piccoli indiani. Oscar Junior
# 3         5  Children_Lit                            Vai all'Inferno, Dante!
# 4         6  Children_Lit                                             Wonder
# ...     ...           ...                                                ...
# 1340   1995      Thriller  Good Girl, Bad Blood: The Sunday Times Bestsel...
# 1341   1996      Thriller             Tempesta di neve e profumo di mandorle
# 1342   1997      Thriller                    La ragazza che guardava l'acqua
# 1343   1998      Thriller  Cronache dal selvaggio West. Hap e Leonard, le...
# 1344   1999      Thriller                                Il valore affettivo
#
# ...

# %%
#filtro per poche reviews

# %%
revi=amazon_ita2['N_Reviews_AZ'].to_list()
r=0

for el in revi:
    if el != 'error' and el > 1000:
        r+=1
r

#pochi hanno tante recensioni e tanti ne hanno poche. Bisognerà equilibrare
# Out:
# 73

# %%
amazon_ita2[amazon_ita2['Genere']=='Children_Lit']
# Out:
#      index        Genere                                              Title  \
# 0        1  Children_Lit  Per questo mi chiamo Giovanni. Da un padre a u...
# 1        3  Children_Lit  Harry Potter e la pietra filosofale Tascabile ...
# 2        4  Children_Lit                Dieci piccoli indiani. Oscar Junior
# 3        5  Children_Lit                            Vai all'Inferno, Dante!
# 4        6  Children_Lit                                             Wonder
# ..     ...           ...                                                ...
# 239    390  Children_Lit              Il libro dei perché. Ediz. illustrata
# 240    392  Children_Lit                       Da grande farò il calciatore
# 241    393  Children_Lit    Il piccolo libro della felicità. Ediz. a colori
# 242    397  Children_Lit                       Fairy Oak. La storia perduta
# 243    399  Children_Lit                                      Il mago di Oz
#
# ...

# %%
amazon_ita2[amazon_ita2['Genere']=='Romance']
# Out:
#      index   Genere                                              Title  \
# 244    400  Romance                      Quando si avvera un desiderio
# 245    401  Romance               La sorella perduta. Le sette sorelle
# 246    402  Romance                   L'ultima notte della nostra vita
# 247    403  Romance              Ally nella tempesta. Le sette sorelle
# 248    404  Romance              La ragazza del sole. Le sette sorelle
# ..     ...      ...                                                ...
# 557    791  Romance                                  Il segreto di Eva
# 558    792  Romance  La lettera d'oro: Il primo caso del detective ...
# 559    793  Romance                   Il museo delle promesse infrante
# 560    794  Romance  The Dutch House: Longlisted for the Women's Pr...
# 561    797  Romance                                          Moonlight
#
#                          Author            ISBN Num_Pages_AZ  \
# ...

# %%
amazon_ita2[amazon_ita2['Genere']=='Fantasy']
# Out:
#      index   Genere                                              Title  \
# 562    800  Fantasy                           La casa sul mare celeste
# 563    801  Fantasy  Your name. Collection box: 1-3 [Tre volumi ind...
# 564    802  Fantasy      Harry Potter and the Philosopher's Stone: 1/7
# 565    803  Fantasy                            La boutique del mistero
# 566    804  Fantasy                S. La nave di Teseo di V. M. Straka
# ..     ...      ...                                                ...
# 789   1188  Fantasy    Il fuoco di Acrab. La saga del Dominio (Vol. 2)
# 790   1194  Fantasy  The Left Hand of Darkness: 50th Anniversary Ed...
# 791   1196  Fantasy  Un nuovo regno. Le guerre del mondo emerso (Vo...
# 792   1197  Fantasy  Signore delle ombre. Dark artifices. Shadowhun...
# 793   1198  Fantasy      Le lame di Myra. La saga del Dominio (Vol. 1)
#
#                          Author             ISBN Num_Pages_AZ  \
# ...

# %%
amazon_ita2[amazon_ita2['Genere']=='Scifi']
# Out:
#       index Genere                                              Title  \
# 794    1200  Scifi                    Dune. Il ciclo di Dune (Vol. 1)
# 795    1201  Scifi  Frank Herbert Messia di Dune Il ciclo di Dune:...
# 796    1203  Scifi                                     Fahrenheit 451
# 797    1204  Scifi  I figli di Dune. Il ciclo di Dune. Ediz. illus...
# 798    1205  Scifi                      Fondazione. Il ciclo completo
# ...     ...    ...                                                ...
# 1006   1585  Scifi                   Starsight. Missione nello spazio
# 1007   1588  Scifi      Il rosso di Marte. Trilogia di Marte (Vol. 1)
# 1008   1590  Scifi                   Pericoli di un viaggio nel tempo
# 1009   1592  Scifi  Prelude to Foundation [Lingua inglese] [Lingua...
# 1010   1594  Scifi  Juggernaut. Terminal war. La guerra conclusiva...
#
#                                     Author            ISBN Num_Pages_AZ  \
# ...

# %%
amazon_ita2[amazon_ita2['Genere']=='Thriller']
# Out:
#       index    Genere                                              Title  \
# 1011   1600  Thriller                                    Bolle di sapone
# 1012   1601  Thriller                          Un fuoco che brucia lento
# 1013   1602  Thriller                             Il visitatore notturno
# 1014   1603  Thriller                         Trilogia della città di K.
# 1015   1604  Thriller                                Quelli che uccidono
# ...     ...       ...                                                ...
# 1340   1995  Thriller  Good Girl, Bad Blood: The Sunday Times Bestsel...
# 1341   1996  Thriller             Tempesta di neve e profumo di mandorle
# 1342   1997  Thriller                    La ragazza che guardava l'acqua
# 1343   1998  Thriller  Cronache dal selvaggio West. Hap e Leonard, le...
# 1344   1999  Thriller                                Il valore affettivo
#
#                           Author             ISBN Num_Pages_AZ  \
# ...

# %%
amazon_ita2.to_csv('Meta_Amazon_IT.csv')

# %%
#per ora basta. Poi il resto puoi filtrarelo su anobii

# %%
#PULIZIA MANUALE, CODICE VECCHIO

# %%
count=0
ids=[]
for el in distr_rating:
    if len(el)>5:
        ids.append(count)
    count+=1
#ids

# %%
#sistemazione manuale distr_rating

distr_rating[3].pop(3)
distr_rating[3].pop(3)
distr_rating[5].pop(3)
distr_rating[5].pop(3)
distr_rating[8].pop(3)
distr_rating[8].pop(3)
distr_rating[13].pop(3)
distr_rating[13].pop(3)
distr_rating[29].pop(3)
distr_rating[29].pop(3)
distr_rating[32].pop(4)
distr_rating[32].pop(4)
distr_rating[50].pop(3)
distr_rating[50].pop(3)
distr_rating[50].pop(3)
distr_rating[51].pop(3)
distr_rating[51].pop(3)
distr_rating[51].pop(3)
distr_rating[52].pop(4)
distr_rating[52].pop(4)
distr_rating[53].pop(2)
distr_rating[53].pop(2)
distr_rating[53].pop(2)
distr_rating[53].pop(2)
distr_rating[53].pop(2)
distr_rating[53].pop(2)
distr_rating[62].pop(3)
distr_rating[62].pop(3)
distr_rating[69].pop(4)
distr_rating[69].pop(4)
distr_rating[93].pop(3)
distr_rating[93].pop(3)
distr_rating[98].pop(1)
distr_rating[98].pop(1)
distr_rating[98].pop(1)
distr_rating[98].pop(1)
distr_rating[98].pop(1)
distr_rating[98].pop(1)
distr_rating[98].pop(1)
distr_rating[98].pop(1)
distr_rating[108].pop(3)
distr_rating[108].pop(3)
distr_rating[109].pop(2)
distr_rating[109].pop(2)
distr_rating[109].pop(2)
distr_rating[109].pop(2)
distr_rating[109].pop(2)
distr_rating[109].pop(2)
distr_rating[122].pop(4)
distr_rating[122].pop(4)
distr_rating[129].pop(3)
distr_rating[129].pop(3)
distr_rating[129].pop(3)
distr_rating[129].pop(3)
distr_rating[138].pop(4)
distr_rating[138].pop(4)
distr_rating[142].pop(4)
distr_rating[142].pop(4)
distr_rating[143].pop(4)
distr_rating[143].pop(4)
distr_rating[167].pop(4)
distr_rating[167].pop(4)
distr_rating[176].pop(3)
distr_rating[176].pop(3)
distr_rating[176].pop(3)
distr_rating[176].pop(3)
distr_rating[183].pop(3)
distr_rating[183].pop(3)
distr_rating[188].pop(1)
distr_rating[188].pop(1)
distr_rating[188].pop(1)
distr_rating[188].pop(1)
distr_rating[191].pop(2)
distr_rating[191].pop(2)
distr_rating[191].pop(4)
distr_rating[191].pop(4)
distr_rating[226].pop(4)
distr_rating[226].pop(4)
distr_rating[253].pop(3)
distr_rating[253].pop(3)
distr_rating[253].pop(3)
distr_rating[253].pop(3)

# %%
#correzione codici isbn

li_id=[]
count=0
for el in isbn_code:
    if len(el)>14 or el[-1]=='\n':
        li_id.append(count)
    count+=1
li_id
# Out:
# [8, 33, 49, 58, 102, 112, 120, 131, 133, 146, 156, 218]

# %%
#correzione manuale dei pochi elementi errati

isbn_code[8]='978-8853019370'
isbn_code[33]='978-1408855652'
isbn_code[49]='978-2070612758'
isbn_code[58]='978-8869660337'
isbn_code[102]='978-0099555254'
isbn_code[112]='978-8466329088'
isbn_code[120]='978-1786495259'
isbn_code[131]='978-8831982139'
isbn_code[133]='978-0141036137'
isbn_code[146]='978-1408855652'
isbn_code[156]='978-8804668084'
isbn_code[218]='978-8845907296'

# %%
#creazione dataframe

amazon_ita=pd.DataFrame(list(zip(gen,title,author,isbn_code,n_pages,avg_rat,distr_rating,n_voti,n_review)), columns=['Genere','Title','Author','ISBN','Num_Pages','Stars','Distr_Rat','N_Votes','N_Reviews'])
#amazon_ita=amazon_ita.reset_index()
#affil_covid_def=affil_covid_def.drop('index',axis=1)
amazon_ita
# Out:
#            Genere                                              Title  \
# 0    Children_Lit  Per questo mi chiamo Giovanni. Da un padre a u...
# 1    Children_Lit  Harry Potter e la pietra filosofale Tascabile ...
# 2    Children_Lit  Harry Potter e la camera dei segreti Tascabile...
# 3    Children_Lit  Harry Potter e il prigioniero di Azkaban Tasca...
# 4    Children_Lit                Dieci piccoli indiani. Oscar Junior
# ..            ...                                                ...
# 251      Thriller                                    Sangue Inquieto
# 252      Thriller                             La Salita dei Saponari
# 253      Thriller                                Cose di Cosa Nostra
# 254      Thriller  We Were Liars: Winner of the YA Goodreads Choi...
# 255      Thriller                                  Viaggio nel tempo
#
#                               Author            ISBN Num_Pages  Stars  \
# ...

# %%
amazon_ita.to_csv('Amazon_IT.csv')

# %%
#integrazione altri 48 libri (3 pagine) sci-fi per arrivare ai 100 richiesti
#prendiamo tutti i link dei libri per questo genere (64) 
#fantasy e sci-fi italiano


url= "https://www.amazon.it/s?i=stripbooks&bbn=411664031&rh=n%3A411663031%2Cn%3A1345828031%2Cp_6%3AA1IZZI10GE0KEI&dc&qid=1627593643&rnid=411664031&ref=sr_nr_n_10"
driver.get(url)  
lista_lnk=[]
page_lnk=driver.find_element_by_xpath("//span[@class='s-pagination-strip']/a[@class='s-pagination-item s-pagination-button']").get_attribute('href')
p1=page_lnk[0:116]
p2=page_lnk[117:-1]
link=p1+str(1)+p2+str(1)

for i in range(5,8,1):
    link=p1+str(i)+p2+str(i)
    url_page=str(link)
    driver.get(url_page)
    
    page_links=driver.find_elements_by_xpath("//a[@class='a-link-normal s-no-outline']")
    for el in page_links:
        lista_lnk.append(el.get_attribute('href'))
        
print(len(lista_lnk))
# Out:
# 48

# %%
#creiamo liste vuote per poter poi fare i dataframe
title=[]
author=[]
isbn_code=[]
n_pages=[]
avg_rat=[]
distr_rating=[]
n_voti=[]
n_review=[]
#gen=[]  #dopo la si filla, ma nel for esterno

for link in lista_lnk:
    time.sleep(2)
    driver.get(link)
    
    #titolo
    titolo = driver.find_element_by_xpath("//div[@class='a-section a-spacing-none']/h1[@id='title']/span[@id='productTitle']")
    title.append(titolo.text)
    
    #autore
    try:
        autore = driver.find_element_by_xpath("//span[@class='author notFaded']")
        author.append(autore.text)
    except:
        author.append('Not found')
    
    #isbn
    isbn = driver.find_elements_by_xpath("//ul[@class='a-unordered-list a-nostyle a-vertical a-spacing-none detail-bullet-list']/li/span[@class='a-list-item']")
    code = isbn[4].get_attribute('textContent')
    isbn_code.append(code[16:30])
    
    #numero pagine
    try:
        pages = isbn[2].get_attribute('textContent')
        p=re.findall(r'\d+', pages)
        n_pages.append(p[0])
        
    except IndexError:  #capita che ci sia un codiice ASIN che sballa le cose
        pages = isbn[3].get_attribute('textContent')
        p=re.findall(r'\d+', pages)
        n_pages.append(p[0])
    
    #stars
    stars = driver.find_element_by_xpath("//div[@id='reviewsMedley']/div[@class='a-fixed-left-grid-inner']/div[@class='a-fixed-left-grid-col a-col-left']/div[@class='a-section a-spacing-none a-spacing-top-mini cr-widget-ACR']/div[@class='a-fixed-left-grid AverageCustomerReviews a-spacing-small']/div[@class='a-fixed-left-grid-inner']/div[@class='a-fixed-left-grid-col a-col-left']/i[@data-hook='average-star-rating']/span[@class='a-icon-alt']")
    stars = stars.get_attribute('textContent')
    avg_rat.append(float(stars[0:3].replace(',','.')))
    
    #distributed rating
    dist_rat = driver.find_element_by_xpath("//div[@id='reviewsMedley']/div[@class='a-fixed-left-grid-inner']/div[@class='a-fixed-left-grid-col a-col-left']/span[@class='cr-widget-Histogram']")
    dist_rat = dist_rat.get_attribute('textContent')
    distr_rating.append(re.findall(r'\d+\%' ,dist_rat))


    #numero voti e recensioni 
    
    time.sleep(1)
    all_rev=driver.find_element_by_xpath("//a[@data-hook='see-all-reviews-link-foot']")
    n_rev_link=all_rev.get_attribute('href')
    url2=str(n_rev_link)
    driver.get(url2)
    n_rev=driver.find_element_by_xpath("//div[@data-hook='cr-filter-info-review-rating-count']/span")
    v_r=n_rev.text.split('|')
    count=0
    for el in v_r:
        el=el.replace('.','')
        if count==0:
            n_voti.append(float(re.findall(r'\d+' ,el)[0]))
            count+=1
        else:
            n_review.append(float(re.findall(r'\d+' ,el)[0]))

# %%
isbn_code[16]='978-1408856772'
isbn_code[17]='978-8834738887'
isbn_code
# Out:
# ['978-8817143448',
#  '978-8830103924',
#  '978-8804734420',
#  '978-8845299209',
#  '978-1526626585',
#  '978-8807903472',
#  '978-8893810753',
#  '978-8822623508',
#  '978-8804738015',
#  '978-8880339236',
#  '978-8845299698',
#  '978-8833572635',
#  '978-8804716679',
#  '978-8817149990',
#  '978-8834741634',
#  '978-8830101982',
#  '978-1408856772',
#  '978-8834738887',
#  '978-8804734369',
#  '978-8833315157',
#  '978-8845298974',
#  '978-8830102712',
#  '978-8833572239',
#  '978-8804717959',
#  '978-8833312415',
#  '978-8817098823',
#  '978-8817093927',
#  '978-0007263516',
#  '978-8804727620',
#  '978-8804658245',
#  '978-8804727606',
#  '978-8804718277',
#  '978-8834741948',
#  '978-8834903186',
#  '978-8868362713',
#  '978-8884519863',
#  '979-1259670366',
#  '978-8804735335',
#  '978-8817069601',
#  '978-8804717966',
#  '978-8817105378',
#  '979-1259670359',
#  '978-8834906576',
#  '978-8804717973',
#  '978-8804674108',
#  '978-8497592208',
#  '978-8868361136',
# ...

# %%
#rendiamo interi i valori di n_voti e n_review
for i in range(0,48,1):
    n_voti[i]=int(n_voti[i])
    n_review[i]=int(n_review[i])

# %%
#valutiamo quali liste rating distribuito hanno problemi

count=0
ids=[]
for el in distr_rating:
    if len(el)>5:
        ids.append(count)
    count+=1
ids
# Out:
# [4, 7, 8, 19, 26, 28, 32, 33, 37, 41, 42, 47]

# %%
distr_rating[4].pop(3)
distr_rating[4].pop(3)
distr_rating[7].pop(3)
distr_rating[7].pop(3)
distr_rating[7].pop(3)
distr_rating[7].pop(3)
distr_rating[8].pop(2)
distr_rating[8].pop(2)
distr_rating[8].pop(2)
distr_rating[8].pop(2)
distr_rating[19].pop(2)
distr_rating[19].pop(2)
distr_rating[19].pop(4)
distr_rating[19].pop(4)
distr_rating[26].pop(4)
distr_rating[26].pop(4)
distr_rating[28].pop(2)
distr_rating[28].pop(2)
distr_rating[28].pop(2)
distr_rating[28].pop(2)
distr_rating[28].pop(2)
distr_rating[28].pop(2)
distr_rating[32].pop(0)
distr_rating[32].pop(0)
distr_rating[32].pop(0)
distr_rating[32].pop(0)
distr_rating[32].pop(0)
distr_rating[32].pop(0)
distr_rating[32].pop(0)
distr_rating[32].pop(0)
distr_rating[33].pop(2)
distr_rating[33].pop(2)
distr_rating[33].pop(2)
distr_rating[33].pop(2)
distr_rating[37].pop(3)
distr_rating[37].pop(3)
distr_rating[37].pop(3)
distr_rating[37].pop(3)
distr_rating[41].pop(4)
distr_rating[41].pop(4)
distr_rating[42].pop(2)
distr_rating[42].pop(2)
distr_rating[42].pop(2)
distr_rating[42].pop(2)
distr_rating[42].pop(2)
distr_rating[42].pop(2)
distr_rating[47].pop(3)
distr_rating[47].pop(3)

# %%
from itertools import repeat
gen=[]
gen.extend(repeat('Fantasy_Scifi',48))

# %%
#creazione dataframe

amazon_ita_scifi=pd.DataFrame(list(zip(gen,title,author,isbn_code,n_pages,avg_rat,distr_rating,n_voti,n_review)), columns=['Genere','Title','Author','ISBN','Num_Pages_AZ','Stars_AZ','Distr_Rat_AZ','N_Votes_AZ','N_Reviews_AZ'])
#amazon_ita=amazon_ita.reset_index()
#affil_covid_def=affil_covid_def.drop('index',axis=1)
amazon_ita_scifi
# Out:
#            Genere                                              Title  \
# 0   Fantasy_Scifi                                             Legend
# 1   Fantasy_Scifi                L'ombra dello scorpione (The stand)
# 2   Fantasy_Scifi  La catena di ferro. Shadowhunters. The last ho...
# 3   Fantasy_Scifi    Lo Hobbit. Un viaggio inaspettato. Ediz. deluxe
# 4   Fantasy_Scifi  Harry Potter and the Philosopher’s Stone: Mina...
# 5   Fantasy_Scifi                      Viaggio al centro della Terra
# 6   Fantasy_Scifi                    La storia infinita. Nuova ediz.
# 7   Fantasy_Scifi  Il fiore della felicità. Demon slayer. Kimetsu...
# 8   Fantasy_Scifi  Shadowhunters. Dark Artifices: Signora della m...
# 9   Fantasy_Scifi                                       Io sono Zero
# 10  Fantasy_Scifi  Il cacciatore di Draghi, ovvero Giles l'Agrico...
# 11  Fantasy_Scifi                        La biblioteca di mezzanotte
# 12  Fantasy_Scifi  Città delle anime perdute. Shadowhunters. The ...
# ...

# %%
#importo il file di AMAZON IT ed estraggo la lista degli ISBN (o dei titoli se con ISBN non riesci)
columns=['Genere','Title','Author','ISBN','Num_Pages_AZ','Stars_AZ','Distr_Rat_AZ','N_Votes_AZ','N_Reviews_AZ']
amazon_ita=pd.read_csv("C:\\Users\\aless\\OneDrive\\Desktop\\Laurea_magistrale\\Tesi\\Amazon_IT.csv",names=columns)
amazon_ita=amazon_ita[1:].reset_index()
amazon_ita=amazon_ita.drop('index',axis=1)
amazon_ita
# Out:
#            Genere                                              Title  \
# 0    Children_Lit  Harry Potter e la pietra filosofale Tascabile ...
# 1    Children_Lit  Harry Potter e la camera dei segreti Tascabile...
# 2    Children_Lit  Harry Potter e il prigioniero di Azkaban Tasca...
# 3    Children_Lit                Dieci piccoli indiani. Oscar Junior
# 4    Children_Lit  Harry Potter e l'Ordine della Fenice Tascabile...
# ..            ...                                                ...
# 250      Thriller                                    Sangue Inquieto
# 251      Thriller                             La Salita dei Saponari
# 252      Thriller                                Cose di Cosa Nostra
# 253      Thriller  We Were Liars: Winner of the YA Goodreads Choi...
# 254      Thriller                                  Viaggio nel tempo
#
#                               Author            ISBN Num_Pages_AZ Stars_AZ  \
# ...

# %%
#crea due gruppi dal set di dati iniziale:
#prima del thriller e dopo il thriller, e in mezzo ci inserisci amazon_ita_scifi

pre=amazon_ita[:191]
post=amazon_ita[191:]

frames = [pre,amazon_ita_scifi,post]
result = pd.concat(frames)
result
# Out:
#            Genere                                              Title  \
# 0    Children_Lit  Harry Potter e la pietra filosofale Tascabile ...
# 1    Children_Lit  Harry Potter e la camera dei segreti Tascabile...
# 2    Children_Lit  Harry Potter e il prigioniero di Azkaban Tasca...
# 3    Children_Lit                Dieci piccoli indiani. Oscar Junior
# 4    Children_Lit  Harry Potter e l'Ordine della Fenice Tascabile...
# ..            ...                                                ...
# 250      Thriller                                    Sangue Inquieto
# 251      Thriller                             La Salita dei Saponari
# 252      Thriller                                Cose di Cosa Nostra
# 253      Thriller  We Were Liars: Winner of the YA Goodreads Choi...
# 254      Thriller                                  Viaggio nel tempo
#
#                               Author            ISBN Num_Pages_AZ Stars_AZ  \
# ...

# %%
result.to_csv('AmazonIT.csv')
