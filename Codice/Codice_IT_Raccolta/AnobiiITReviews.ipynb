# %%
import re
import time
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
PATH='C:\\Users\\aless\\OneDrive\\Desktop\\Laurea_magistrale\\Tesi\\chromedriver.exe'
driver = webdriver.Chrome(PATH)

# %%
#lista titoli tenuti
import pandas as pd
meta_ita=pd.read_csv("C:\\Users\\aless\\OneDrive\\Desktop\\Laurea_magistrale\\Tesi\\Dati\\Dati_Italia\\Metadati_ITA.csv")
meta_ita
#booklist
# Out:
#      Unnamed: 0        Genere  \
# 0             0  Children_Lit
# 1             1  Children_Lit
# 2             2  Children_Lit
# 3             3  Children_Lit
# 4             4  Children_Lit
# ..          ...           ...
# 995         995         Scifi
# 996         996         Scifi
# 997         997         Scifi
# 998         998         Scifi
# 999         999         Scifi
#
#                                                  Title  \
# 0    Per questo mi chiamo Giovanni. Da un padre a u...
# 1    Harry Potter e la pietra filosofale Tascabile ...
# 2                  Dieci piccoli indiani. Oscar Junior
# 3                              Vai all'Inferno, Dante!
# 4                                               Wonder
# ..                                                 ...
# 995                              Come fermare il tempo
# 996                   Starsight. Missione nello spazio
# 997      Il rosso di Marte. Trilogia di Marte (Vol. 1)
# 998                   Pericoli di un viaggio nel tempo
# 999  Prelude to Foundation [Lingua inglese] [Lingua...
#
#                                    Author            ISBN  Num_Pages_AZ  \
# 0                Luigi Garlando (Autore),  978-8817141727           159
# 1                 J. K. Rowling (Autore),  978-8831003384           310
# 2               Agatha Christie (Autore),  978-8804616986           229
# 3                 Luigi Garlando (Autore)  978-8817144988           500
# 4                 R. J. Palacio (Autore),  978-8809058347           288
# ..                                    ...             ...           ...
# 995                   Matt Haig (Autore),  978-8833573298           368
# 996           Brandon Sanderson (Autore),  978-8834433843           488
# 997        Kim Stanley Robinson (Autore),  978-8834740330           468
# 998           Joyce Carol Oates (Autore),  978-8834604557           352
# 999  Isaac Asimov (Autore, Collaboratore)  978-0553278392           493
#
#                                            Pub_Date_AZ  \
# 0    \nEditore\n‏\n:\n‎\n\nBUR Biblioteca Univ. Riz...
# 1    \nEditore\n‏\n:\n‎\n\nSalani; New edizione (23...
# 2    \nEditore\n‏\n:\n‎\n\nMondadori; 2° edizione (...
# 3     \nEditore\n‏\n:\n‎\n\nRizzoli (12 maggio 2020)\n
# 4    \nEditore\n‏\n:\n‎\n\nGiunti Editore (8 maggio...
# ..                                                 ...
# 995       \nEditore\n‏\n:\n‎\n\nE/O (15 maggio 2021)\n
# 996  \nEditore\n‏\n:\n‎\n\nArmenia (29 gennaio 2020)\n
# 997    \nEditore\n‏\n:\n‎\n\nFanucci (2 luglio 2020)\n
# 998  \nEditore\n‏\n:\n‎\n\nLa nave di Teseo (28 gen...
# 999  \nEditore\n‏\n:\n‎\n\nRandom USA; Reissue ediz...
#
#                            Lingua_AZ  Avg_Rat_AZ  \
# 0    \nLingua\n‏\n:\n‎\n\nItaliano\n         4.7
# 1    \nLingua\n‏\n:\n‎\n\nItaliano\n         4.8
# 2    \nLingua\n‏\n:\n‎\n\nItaliano\n         4.7
# 3    \nLingua\n‏\n:\n‎\n\nItaliano\n         4.6
# 4    \nLingua\n‏\n:\n‎\n\nItaliano\n         4.7
# ..                               ...         ...
# 995  \nLingua\n‏\n:\n‎\n\nItaliano\n         4.2
# 996  \nLingua\n‏\n:\n‎\n\nItaliano\n         4.5
# 997  \nLingua\n‏\n:\n‎\n\nItaliano\n         3.8
# 998  \nLingua\n‏\n:\n‎\n\nItaliano\n         3.1
# 999   \nLingua\n‏\n:\n‎\n\nInglese\n         4.7
#
#                             Distr_Rat_AZ  ...  N_Reviews_AZ  \
# 0       ['81%', '14%', '3%', '1%', '1%']  ...         758.0
# 1       ['84%', '11%', '3%', '1%', '1%']  ...         835.0
# 2       ['76%', '18%', '4%', '1%', '1%']  ...         190.0
# 3       ['77%', '15%', '5%', '1%', '2%']  ...         107.0
# 4       ['80%', '14%', '4%', '1%', '2%']  ...         697.0
# ..                                   ...  ...           ...
# 995    ['53%', '27%', '10%', '5%', '5%']  ...          30.0
# 996     ['62%', '28%', '8%', '1%', '1%']  ...          21.0
# 997    ['42%', '17%', '28%', '7%', '6%']  ...          22.0
# 998  ['25%', '14%', '24%', '19%', '19%']  ...           2.0
# 999     ['77%', '16%', '5%', '1%', '1%']  ...         292.0
#
#                                                Link_AZ Num_Pag_AN N_Votes_AN  \
# 0    https://www.amazon.it/questo-Giovanni-racconto...        159        999
# 1    https://www.amazon.it/Harry-Potter-pietra-filo...      error      36470
# 2    https://www.amazon.it/Dieci-piccoli-indiani-Ag...      error      16117
# 3    https://www.amazon.it/Vai-allInferno-Dante-Lui...      error         11
# 4    https://www.amazon.it/Wonder-R-J-Palacio/dp/88...        285       1777
# ..                                                 ...        ...        ...
# 995  https://www.amazon.it/Come-fermare-tempo-Matt-...      error          0
# 996  https://www.amazon.it/Starsight-Missione-spazi...      error         19
# 997  https://www.amazon.it/rosso-Marte-Trilogia-Mar...      error          0
# 998  https://www.amazon.it/Pericoli-viaggio-tempo-J...      error         34
# 999  https://www.amazon.it/Prelude-foundation-Isaac...      error       2837
#
#      N_Reviews_AN  Avg_Rat_AN                  Pub_Date_AN  \
# 0             191        4.35  Editore\nRizzoli (Best Bur)
# 1            2045        4.28                        error
# 2            1825        4.36                        error
# 3               2        3.45                        error
# 4             327        4.22              Editore\nGiunti
# ..            ...         ...                          ...
# 995             0        0.00                        error
# 996             5        4.39                        error
# 997             0        0.00                        error
# 998            10        2.66                        error
# 999           151        4.18                        error
#
#                                    Genere_Suggerito_AN  \
# 0           [' Bambini ', ' Narrativa & Letteratura ']
# 1                                                error
# 2                                                error
# 3                                                error
# 4    [' Adolescenti ', ' Bambini ', ' Narrativa & L...
# ..                                                 ...
# 995                                              error
# 996                            Fantascienza & Fantasy
# 997                                              error
# 998                                              error
# 999                                              error
#
#                                        Lingua_AN  \
# 0    Riguardo questa edizione\nTutte le edizioni
# 1                                          error
# 2                                          error
# 3                                          error
# 4    Riguardo questa edizione\nTutte le edizioni
# ..                                           ...
# 995                                        error
# 996                                        error
# 997                                        error
# 998                                        error
# 999                                        error
#
#                                                Link_AN
# 0    https://www.anobii.com/search/978-8817141727/b...
# 1    https://www.anobii.com/search/978-8831003384/b...
# 2    https://www.anobii.com/search/978-8804616986/b...
# 3    https://www.anobii.com/search/978-8817144988/b...
# 4    https://www.anobii.com/search/978-8809058347/b...
# ..                                                 ...
# 995  https://www.anobii.com/search/978-8833573298/b...
# 996  https://www.anobii.com/search/978-8834433843/b...
# 997  https://www.anobii.com/search/978-8834740330/b...
# 998  https://www.anobii.com/search/978-8834604557/b...
# 999  https://www.anobii.com/search/978-0553278392/b...
#
# [1000 rows x 21 columns]

# %%
# title e isbn handling
title=meta_ita['Title'].to_list()
isbn=meta_ita['ISBN'].to_list()
gen=meta_ita['Genere'].to_list()
num_rece=meta_ita['N_Reviews_AN'].to_list()
anobii_lnk=meta_ita['Link_AN'].to_list()

# %%
anobii_lnk[:20]
# Out:
# ['https://www.anobii.com/search/978-8817141727/books',
#  'https://www.anobii.com/search/978-8831003384/books',
#  'https://www.anobii.com/search/978-8804616986/books',
#  'https://www.anobii.com/search/978-8817144988/books',
#  'https://www.anobii.com/search/978-8809058347/books',
#  'https://www.anobii.com/search/978-8804598893/books',
#  'https://www.anobii.com/search/978-8804598909/books',
#  'https://www.anobii.com/search/978-8831003391/books',
#  'https://www.anobii.com/search/978-8893810739/books',
#  'https://www.anobii.com/search/978-8804680680/books',
#  'https://www.anobii.com/search/978-8896918449/books',
#  'https://www.anobii.com/search/978-8879268493/books',
#  'https://www.anobii.com/search/978-8831003414/books',
#  'https://www.anobii.com/search/978-8867226207/books',
#  'https://www.anobii.com/search/978-8831003438/books',
#  'https://www.anobii.com/search/978-8831003445/books',
#  'https://www.anobii.com/search/978-8804725398/books',
#  'https://www.anobii.com/search/978-8893810746/books',
#  'https://www.anobii.com/search/978-8868369804/books',
#  'https://www.anobii.com/search/978-8831004114/books']

# %%
#creiamo liste vuote per poter poi fare i dataframe
#per queste due liste, ogni volta che passiamo in rassegna ad un oggetto webdriver il li_reviews, appendiamo anche a loro
titoli=[]
isbn_code=[]
genere=[]

#metadata reviews
userlist=[]
ratings=[]
rev_date=[]
rev_content=[]
n_likes=[]

# %%
no_lnk=0  #per tenere conto di quanti link non vengono presi (da usare in fase ultima, non nelle prove)
number=-1

for lnk in anobii_lnk:
    number+=1
    #time.sleep(2)
    flag=0
    #otteniamo il link con ISBN
    try:
        try:
            driver.get(lnk)
        except:
            time.sleep(5)
            driver.get(lnk)
    except:

            userlist.append('no_link')
            ratings.append('no_link')
            rev_date.append('no_link')
            rev_content.append('no_link')
            n_likes.append('no_link')
            titoli.append(title[number])
            isbn_code.append(isbn[number])
            genere.append(gen[number])
            continue
    
    try:
        
        try:
            lnk2=driver.find_element_by_xpath("//div[@class='col-cover']/a['_ngcontent-serverapp-c194']").get_attribute('href')
            driver.get(lnk2)
            flag+=1   #flag per attivare codice
        except:
            time.sleep(3)
            lnk2=driver.find_element_by_xpath("//div[@class='col-cover']/a['_ngcontent-serverapp-c194']").get_attribute('href')
            driver.get(lnk2)
            flag+=1   #flag per attivare codice
            
    except:

            userlist.append('no_link')
            ratings.append('no_link')
            rev_date.append('no_link')
            rev_content.append('no_link')
            n_likes.append('no_link')
            titoli.append(title[number])
            isbn_code.append(isbn[number])
            genere.append(gen[number])
            no_lnk+=1
            time.sleep(1)
    
    if flag==1:
        #ora che siamo dentro la pagina delle statistiche:
    

        n_rev=num_rece[number]  #sfruttiamo la lista relativa al numero di recensioni proveniente dai metadati
        
        if n_rev==0 or type(n_rev) != int:
            userlist.append('error')
            ratings.append('error')
            rev_date.append('error')
            rev_content.append('error')
            n_likes.append('error')
            titoli.append(title[number])
            isbn_code.append(isbn[number])
            genere.append(gen[number])
            continue
            
        if n_rev>0 and n_rev<10:
            n_rev=10

            
        #una volta ottenuto il numero di recensioni si entra nella pagina delle reviews:
        try:
            try:
                driver.get(str(lnk2)+str("/reviews"))
            except:
                time.sleep(5)
                driver.get(str(lnk2)+str("/reviews"))
        except:

            userlist.append('no_link')
            ratings.append('no_link')
            rev_date.append('no_link')
            rev_content.append('no_link')
            n_likes.append('no_link')
            titoli.append(title[number])
            isbn_code.append(isbn[number])
            genere.append(gen[number])
            continue
            
            
        if int(n_rev//10) == int(n_rev/10):  #se il numero di recensioni è divisibile per 10
            
            for i in range(1,int(n_rev/10 +1),1):  #max 10 reviews per pagina
                
                time.sleep(1)  #vitale
                #metadati recensioni:
                
                try:
                    try:
                        time.sleep(3)
                        li_reviews=driver.find_elements_by_xpath("//div[@class='ng-star-inserted']")
                    except:
                        time.sleep(5)
                        li_reviews=driver.find_elements_by_xpath("//div[@class='ng-star-inserted']")
                except:

                    userlist.extend(['error' for x in range(10)])
                    ratings.extend(['error' for x in range(10)])
                    rev_date.extend(['error' for x in range(10)])
                    rev_content.extend(['error' for x in range(10)])
                    n_likes.extend(['error' for x in range(10)])
                    titoli.extend([title[number] for x in range(10)])
                    isbn_code.extend([isbn[number] for x in range(10)])
                    genere.extend([gen[number] for x in range(10)])  #non specifichiamo la situazione in cui siamo nell'ultima pagina, tanto poi gli errori vengono filtrati
                    continue
                    
                
                    
                #username
                for el in li_reviews:
                    try:
                        user=el.find_element_by_class_name('ml-4').text
                        userlist.append(user)
                        #appendiamo anche titolo e isbn code
                        titoli.append(title[number])
                        isbn_code.append(isbn[number])
                        genere.append(gen[number])
                    except:
                        userlist.append('error')
                        titoli.append(title[number])
                        isbn_code.append(isbn[number])
                        genere.append(gen[number])
                        
                #likes
                try:
                    lik=li_reviews[0].find_elements_by_xpath("//div['_ngcontent-serverapp-c187']/app-number-text['_ngcontent-serverapp-c187']")
                    like=-1
                    for el in lik:
                        elem=el.text
                        if elem != '':
                            if like/2 == like//2: 
                                n_likes.append(elem)
                        like+=1
                except:
                    n_likes.extend(['error' for x in range(len(li_reviews))])
    
                #rating
        
                try:
                    try:
                        rat=li_reviews[0].find_elements_by_xpath("//div[@class='rating-div ng-star-inserted']/ngb-rating[@class='d-inline-flex']")
                        r=0
                        for el in rat:
                            if r//2 == r/2:
                                ratings.append(el.get_attribute('aria-valuenow'))
                            r+=1
                        if r < t*2:
                            ratings.extend(['error' for x in range(int((2*t-r)/2))])
                        
                    except:
                        ratings.extend(['error' for x in range(len(li_reviews))])
                except:
                    ratings.extend(['error' for x in range(10)])
    
                    
        
                #review content
                try:
                    try: 
                        time.sleep(1)
                        cont=li_reviews[0].find_elements_by_xpath("//div[@class='row no-gutters']/div[@class='col']/a[@class='unstyled-link ng-star-inserted']/span")
                        for el in cont:
                            rev_content.append(el.get_attribute('textContent'))
                    except:
                        rev_content.extend(['error' for x in range(len(li_reviews))])
                except:
                    rev_content.extend(['error' for x in range(10)])
                
                        
                #date review
                try:   
                    try:
                        dat=li_reviews[0].find_elements_by_xpath("//div[@class='card-footer bg-transparent']/p[@class='small date']")
                        for el in dat:
                            rev_date.append(el.text[:-10])
                    except:
                        rev_date.extend(['error' for x in range(len(li_reviews))])
                except:
                     rev_date.extend(['error' for x in range(10)])
                
                #gestione scorrimento pagine
                
                try:
                    try:
                        driver.get(str(lnk2) + str("/reviews?p=") + str(i+1))
                    except:
                        time.sleep(4)
                        driver.get(str(lnk2) + str("/reviews?p=") + str(i+1))
                except:
                        titoli=titoli[:len(userlist)]
                        isbn_code=isbn_code[:len(userlist)]
                        genere=genere[:len(userlist)]
                        ratings=ratings[:len(userlist)]
                        rev_date=rev_date[:len(userlist)]
                        rev_content=rev_content[:len(userlist)]
                        n_likes=n_likes[:len(userlist)]
                        continue
        


                    
                    
        
        else: #caso in cui le recensioni non siano divisibili per 10. Bisognerà gestire il ciclo differentemente
            
            for i in range(1,int(n_rev/10 +2),1):  #max 10 reviews per pagina
                
                time.sleep(1)  #vitale
                #metadati recensioni:
                
                try:
                    try:
                        time.sleep(3)
                        li_reviews=driver.find_elements_by_xpath("//div[@class='ng-star-inserted']")
                    except:
                        time.sleep(5)
                        li_reviews=driver.find_elements_by_xpath("//div[@class='ng-star-inserted']")
                except:

                    userlist.extend(['error' for x in range(10)])
                    ratings.extend(['error' for x in range(10)])
                    rev_date.extend(['error' for x in range(10)])
                    rev_content.extend(['error' for x in range(10)])
                    n_likes.extend(['error' for x in range(10)])
                    titoli.extend([title[number] for x in range(10)])
                    isbn_code.extend([isbn[number] for x in range(10)])
                    genere.extend([gen[number] for x in range(10)])  #non specifichiamo la situazione in cui siamo nell'ultima pagina, tanto poi gli errori vengono filtrati
                    continue
                    
                
                    
                #username
                for el in li_reviews:
                    try:
                        user=el.find_element_by_class_name('ml-4').text
                        userlist.append(user)
                        #appendiamo anche titolo e isbn code
                        titoli.append(title[number])
                        isbn_code.append(isbn[number])
                        genere.append(gen[number])
                    except:
                        userlist.append('error')
                        titoli.append(title[number])
                        isbn_code.append(isbn[number])
                        genere.append(gen[number])
                        
                #likes
                try:
                    lik=li_reviews[0].find_elements_by_xpath("//div['_ngcontent-serverapp-c187']/app-number-text['_ngcontent-serverapp-c187']")
                    like=-1
                    for el in lik:
                        elem=el.text
                        if elem != '':
                            if like/2 == like//2: 
                                n_likes.append(elem)
                        like+=1
                except:
                    n_likes.extend(['error' for x in range(len(li_reviews))])
    
                #rating
        
                try:
                    try:
                        rat=li_reviews[0].find_elements_by_xpath("//div[@class='rating-div ng-star-inserted']/ngb-rating[@class='d-inline-flex']")
                        r=0
                        for el in rat:
                            if r//2 == r/2:
                                ratings.append(el.get_attribute('aria-valuenow'))
                            r+=1
                        if r < t*2:
                            ratings.extend(['error' for x in range(int((2*t-r)/2))])
                        
                    except:
                        ratings.extend(['error' for x in range(len(li_reviews))])
                except:
                    ratings.extend(['error' for x in range(10)])
    
                    
        
                #review content
                try:
                    try: 
                        time.sleep(1)
                        cont=li_reviews[0].find_elements_by_xpath("//div[@class='row no-gutters']/div[@class='col']/a[@class='unstyled-link ng-star-inserted']/span")
                        for el in cont:
                            rev_content.append(el.get_attribute('textContent'))
                    except:
                        rev_content.extend(['error' for x in range(len(li_reviews))])
                except:
                    rev_content.extend(['error' for x in range(10)])
                
                        
                #date review
                try:   
                    try:
                        dat=li_reviews[0].find_elements_by_xpath("//div[@class='card-footer bg-transparent']/p[@class='small date']")
                        for el in dat:
                            rev_date.append(el.text[:-10])
                    except:
                        rev_date.extend(['error' for x in range(len(li_reviews))])
                except:
                     rev_date.extend(['error' for x in range(10)])
                
                #gestione scorrimento pagine
                
                try:
                    try:
                        driver.get(str(lnk2) + str("/reviews?p=") + str(i+1))
                    except:
                        time.sleep(4)
                        driver.get(str(lnk2) + str("/reviews?p=") + str(i+1))
                except:
                        titoli=titoli[:len(userlist)]
                        isbn_code=isbn_code[:len(userlist)]
                        genere=genere[:len(userlist)]
                        ratings=ratings[:len(userlist)]
                        rev_date=rev_date[:len(userlist)]
                        rev_content=rev_content[:len(userlist)]
                        n_likes=n_likes[:len(userlist)]
                        continue
                    
                    
                    
    #a fine ciclo uniformiamo le lunghezze delle liste con quella di userlist, che è la più precisa nella raccolta:
    titoli=titoli[:len(userlist)]
    isbn_code=isbn_code[:len(userlist)]
    genere=genere[:len(userlist)]
    ratings=ratings[:len(userlist)]
    rev_date=rev_date[:len(userlist)]
    #rev_title=rev_title[:len(userlist)]
    rev_content=rev_content[:len(userlist)]
    n_likes=n_likes[:len(userlist)]
    
    print(number)
    print(len(rev_content))
    print(len(titoli))
    er=0
    for el in rev_content:
        if el=='error'  or  el=='':
            er+=1
    print(er)
    print('\n')
# Out:
# 0
# 1
# 1
# 0
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-121-a815ee630cea> in <module>
#      29         try:
# ---> 30             lnk2=driver.find_element_by_xpath("//div[@class='col-cover']/a['_ngcontent-serverapp-c194']").get_attribute('href')
#      31             driver.get(lnk2)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@class='col-cover']/a['_ngcontent-serverapp-c194']"}
#   (Session info: chrome=94.0.4606.61)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-121-a815ee630cea> in <module>
#      34             time.sleep(3)
# ---> 35             lnk2=driver.find_element_by_xpath("//div[@class='col-cover']/a['_ngcontent-serverapp-c194']").get_attribute('href')
#      36             driver.get(lnk2)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@class='col-cover']/a['_ngcontent-serverapp-c194']"}
#   (Session info: chrome=94.0.4606.61)
#
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-121-a815ee630cea> in <module>
#      44             rev_content.append('no_link')
#      45             n_likes.append('no_link')
# ---> 46             titoli.append(title[number])
#      47             isbn_code.append(isbn[number])
#      48             genere.append(gen[number])
#
# IndexError: list index out of range

# %%
print(len(titoli))
print(len(isbn_code))
print(len(genere))
print(len(userlist))
print(len(ratings))
print(len(rev_date))
print(len(n_likes))
print(len(rev_content))
# Out:
# 900
# 900
# 900
# 900
# 1559
# 900
# 900
# 900

# %%
#creazione dataframe anobii IT
#dovrà essere concatenato allo stesso tipo di dataframe di Amazon

anobii_reviewsIT=pd.DataFrame(list(zip(genere,titoli,isbn_code,userlist,ratings,rev_date,n_likes,rev_content)), columns=['Genere','Title','ISBN','Username','Rating','Date','N_Likes','Review_Content'])
anobii_reviewsIT
# Out:
#            Genere                                              Title  \
# 0    Children_Lit  Per questo mi chiamo Giovanni. Da un padre a u...
# 1    Children_Lit  Per questo mi chiamo Giovanni. Da un padre a u...
# 2    Children_Lit  Per questo mi chiamo Giovanni. Da un padre a u...
# 3    Children_Lit  Per questo mi chiamo Giovanni. Da un padre a u...
# 4    Children_Lit  Per questo mi chiamo Giovanni. Da un padre a u...
# ..            ...                                                ...
# 895  Children_Lit  Harry Potter e la pietra filosofale Tascabile ...
# 896  Children_Lit  Harry Potter e la pietra filosofale Tascabile ...
# 897  Children_Lit  Harry Potter e la pietra filosofale Tascabile ...
# 898  Children_Lit  Harry Potter e la pietra filosofale Tascabile ...
# 899  Children_Lit  Harry Potter e la pietra filosofale Tascabile ...
#
#                ISBN                             Username Rating         Date  \
# 0    978-8817141727                            Silvia 🌸🎨      5  28 lug 2021
# 1    978-8817141727                                  ila    3.5  27 giu 2021
# 2    978-8817141727                        Tommaso Reina      5  23 feb 2021
# 3    978-8817141727                            Cornamuse      5   3 feb 2021
# 4    978-8817141727                              Firmino      5   1 dic 2020
# ..              ...                                  ...    ...          ...
# 895  978-8831003384                                 EMME  error  21 feb 2011
# 896  978-8831003384                              Alehcim  error  13 feb 2011
# 897  978-8831003384  Dolceluna (trasferita su Goodreads)      3   7 feb 2011
# 898  978-8831003384                                 Sary      5   7 feb 2011
# 899  978-8831003384                            universe.      5   6 feb 2011
#
#     N_Likes                                     Review_Content
# 0         0  Avevo letto anni fa il libro sulla vita di Car...
# 1         0  La storia di Giovanni Falcone raccontata da un...
# 2         0  Carta (Biblioteca)Perché Garlando è "Il  libro...
# 3         0  Il coraggio di Giovanni Falcone raccontata ai ...
# 4         0  Tutto nel titolo. Bellissimo il libro, scritto...
# ..      ...                                                ...
# 895       1  ..è difficile recensire oggettivamente quest'o...
# 896       0  Harry Potter è un predestinato: ha una cicatri...
# 897       6  Mi manca già, questo maghetto occhialuto, iniz...
# 898       2   Il signore e la signora Dursley, di Privet Dr...
# 899       0  Tenendo presente che ho fatto la cavolata di v...
#
# [900 rows x 8 columns]

# %%
#PULIZIA DEL DATAFRAME

# %%
anobii_reviewsIT[anobii_reviewsIT['Review_Content']!='']  #molti non mettono il titolo alla review 2/3
#accettabile
# Out:
#             Genere                                              Title  \
# 0     Children_Lit  Per questo mi chiamo Giovanni. Da un padre a u...
# 1     Children_Lit  Per questo mi chiamo Giovanni. Da un padre a u...
# 2     Children_Lit  Per questo mi chiamo Giovanni. Da un padre a u...
# 3     Children_Lit  Per questo mi chiamo Giovanni. Da un padre a u...
# 4     Children_Lit  Per questo mi chiamo Giovanni. Da un padre a u...
# ...            ...                                                ...
# 4291  Children_Lit                                             Wonder
# 4292  Children_Lit                                             Wonder
# 4293  Children_Lit                                             Wonder
# 4294  Children_Lit                                             Wonder
# 4295  Children_Lit                                             Wonder
#
#                 ISBN            Username Rating         Date  \
# 0     978-8817141727           Silvia 🌸🎨      5  28 lug 2021
# 1     978-8817141727                 ila    3.5  27 giu 2021
# 2     978-8817141727       Tommaso Reina      5  23 feb 2021
# 3     978-8817141727           Cornamuse      5   3 feb 2021
# 4     978-8817141727             Firmino      5   1 dic 2020
# ...              ...                 ...    ...          ...
# 4291  978-8809058347            Claudina      4   2 ago 2013
# 4292  978-8809058347                Vals      5  27 lug 2013
# 4293  978-8809058347  Reginavbergamaschi      4  24 lug 2013
# 4294  978-8809058347       Luigi De Rosa      4   8 lug 2013
# 4295  978-8809058347             Annissa  error  16 mag 2013
#
#                                          Review_Content
# 0     Avevo letto anni fa il libro sulla vita di Car...
# 1     La storia di Giovanni Falcone raccontata da un...
# 2     Carta (Biblioteca)Perché Garlando è "Il  libro...
# 3     Il coraggio di Giovanni Falcone raccontata ai ...
# 4     Tutto nel titolo. Bellissimo il libro, scritto...
# ...                                                 ...
# 4291  Dopo svariati giorni che ho letto questo libro...
# 4292  Bello e delicato, questo libro sa "parlare" ad...
# 4293  Scritto con maestria. Oltre la delicatezza di ...
# 4294   August Pullman, per tutti Auggie, è un ragazz...
# 4295  Credo sia un libro che vale la pena di leggere...
#
# [4273 rows x 7 columns]

# %%
#analisi no link

# %%
anobii_reviewsIT[anobii_reviewsIT['Username']=='no link']
# Out:
# Empty DataFrame
# Columns: [Genere, Title, ISBN, Username, Rating, Date, Review_Content]
# Index: []

# %%
anobii_reviewsIT[anobii_reviewsIT['Review_Content']=='no link']
# Out:
# Empty DataFrame
# Columns: [Genere, Title, ISBN, Username, Rating, Date, Review_Content]
# Index: []

# %%
indici=[]
for index,row in anobii_reviewsIT.iterrows():
    if row['Username'] == 'no link' or row['Date'] == 'no link':
        indici.append(index)
indici
# Out:
# [10765,
#  10794,
#  13868,
#  13897,
#  20190,
#  20201,
#  20914,
#  20925,
#  20943,
#  20954,
#  22136,
#  22147,
#  22184,
#  22195,
#  23214,
#  23225,
#  23334,
#  23345,
#  23734,
#  23745,
#  23911,
#  23922,
#  34901,
#  34920,
#  35026,
#  35045,
#  35948,
#  35949,
#  35967,
#  35968,
#  37048,
#  37059,
#  37060,
#  37067,
#  37078,
#  37079,
#  37650,
#  37651,
#  37669,
#  37670,
#  41624,
#  41643]

# %%
anobii_fin=anobii_reviewsIT.drop(indici, axis=0)
anobii_fin #droppiamo gli inidici che contengono problemi
# Out:
#                                                    Title            ISBN  \
# 0      Harry Potter e la pietra filosofale Tascabile ...  978-8831003384
# 1      Harry Potter e la pietra filosofale Tascabile ...  978-8831003384
# 2      Harry Potter e la pietra filosofale Tascabile ...  978-8831003384
# 3      Harry Potter e la pietra filosofale Tascabile ...  978-8831003384
# 4      Harry Potter e la pietra filosofale Tascabile ...  978-8831003384
# ...                                                  ...             ...
# 55202  We Were Liars: Winner of the YA Goodreads Choi...  978-1471403989
# 55203  We Were Liars: Winner of the YA Goodreads Choi...  978-1471403989
# 55204  We Were Liars: Winner of the YA Goodreads Choi...  978-1471403989
# 55205  We Were Liars: Winner of the YA Goodreads Choi...  978-1471403989
# 55206  We Were Liars: Winner of the YA Goodreads Choi...  978-1471403989
#
#                            Username Rating         Date  \
# 0                     Sonia Peruzzo      5  20 ago 2021
# 1                            Anto70      2  13 ago 2021
# 2                               mgt    4.5  22 lug 2021
# 3         La ragazza con la valigia      5  20 lug 2021
# 4                           Giorgia      5   8 giu 2021
# ...                             ...    ...          ...
# 55202                 Sheere Hikari      3   7 lug 2014
# 55203                  rogercastoro      3   6 lug 2014
# 55204                        missf.      4   4 lug 2014
# 55205          Alessandra Angeletti      4   4 lug 2014
# 55206  Laurina-la-fangirl-assassina      3  21 giu 2014
#
#                                             Review_Title  \
# 0                                Dire perfetto è troppo?
# 1                         Carino e leggero, forse troppo
# 2
# 3                             Edizione Minalima stupenda
# 4
# ...                                                  ...
# 55202
# 55203                          Fai ciò di cui hai paura.
# 55204
# 55205
# 55206  We are liars. We are beautiful and privileged....
#
#                                           Review_Content
# 0      Questo libro ha lanciato la mia fantasia da ra...
# 1      Carino, ma è uno dei pochi casi in cui la scen...
# 2      Ritirato fuori ieri. Magia, magia. Forse anche...
# 3      Questo volume da collezione è magnifico, veste...
# 4      Rileggere questo gioiello con le illustrazioni...
# ...                                                  ...
# 55202  In realtà più due e mezzo che tre stelline. No...
# 55203  diariodiunadipendenza.blogspot.it/2014/07/rece...
# 55204          mah.. secondo me,inutilmente angosciante.
# 55205  L'estate dei segreti perduti di E. Lockhart  u...
# 55206  I won't tell you the plot of this book. It is ...
#
# [55165 rows x 7 columns]

# %%
indici=[]
for index,row in anobii_fin.iterrows():
    if row['Username'] == 'no link' or row['Date'] == 'no link':
        indici.append(index)
indici
# Out:
# []

# %%
#analisi error nelle reviews

# %%
anobii_fin[anobii_fin['Review_Content']=='error']
# Out:
#                                                    Title            ISBN  \
# 5664   Harry Potter e l'Ordine della Fenice Tascabile...  978-8831003421
# 5665   Harry Potter e l'Ordine della Fenice Tascabile...  978-8831003421
# 5666   Harry Potter e l'Ordine della Fenice Tascabile...  978-8831003421
# 5667   Harry Potter e l'Ordine della Fenice Tascabile...  978-8831003421
# 5668   Harry Potter e l'Ordine della Fenice Tascabile...  978-8831003421
# ...                                                  ...             ...
# 34310                            La boutique del mistero  978-8804668084
# 34311                            La boutique del mistero  978-8804668084
# 34312                            La boutique del mistero  978-8804668084
# 34313                            La boutique del mistero  978-8804668084
# 34314                            La boutique del mistero  978-8804668084
#
#                             Username Rating   Date Review_Title Review_Content
# 5664                    Black Swan85      5  error        error          error
# 5665                   Michele Sasso      5  error        error          error
# 5666                        Eleonora      5  error        error          error
# 5667                          Ilaria      4  error        error          error
# 5668                      Gin Harper      4  error        error          error
# ...                              ...    ...    ...          ...            ...
# 34310  Eleclyah (anche su GoodReads)      3  error        error          error
# 34311                   MartinaViola      5  error        error          error
# 34312                      Missile23      5  error        error          error
# 34313                             ΔG      5  error        error          error
# 34314                         ElleCi      3  error        error          error
#
# [70 rows x 7 columns]

# %%
errori=[]
for index,row in anobii_fin.iterrows():
    if row['Review_Content'] == 'error':
        errori.append(index)
errori
# Out:
# [5664,
#  5665,
#  5666,
#  5667,
#  5668,
#  5669,
#  5670,
#  5671,
#  5672,
#  5673,
#  15934,
#  15935,
#  15936,
#  15937,
#  15938,
#  15939,
#  15940,
#  15941,
#  15942,
#  15943,
#  15944,
#  15945,
#  15946,
#  15947,
#  15948,
#  15949,
#  15950,
#  15951,
#  15952,
#  15953,
#  19590,
#  19591,
#  19592,
#  19593,
#  19594,
#  19595,
#  19596,
#  19597,
#  19598,
#  19599,
#  29069,
#  29070,
#  29071,
#  29072,
#  29073,
#  29074,
#  29075,
#  29076,
#  29077,
#  29078,
#  34077,
#  34078,
#  34079,
#  34080,
#  34081,
#  34082,
#  34083,
#  34084,
#  34085,
#  34086,
#  34305,
#  34306,
#  34307,
#  34308,
#  34309,
#  34310,
#  34311,
#  34312,
#  34313,
#  34314]

# %%
anobii_fin=anobii_fin.drop(errori, axis=0)
anobii_fin
# Out:
#                                                    Title            ISBN  \
# 0      Harry Potter e la pietra filosofale Tascabile ...  978-8831003384
# 1      Harry Potter e la pietra filosofale Tascabile ...  978-8831003384
# 2      Harry Potter e la pietra filosofale Tascabile ...  978-8831003384
# 3      Harry Potter e la pietra filosofale Tascabile ...  978-8831003384
# 4      Harry Potter e la pietra filosofale Tascabile ...  978-8831003384
# ...                                                  ...             ...
# 55202  We Were Liars: Winner of the YA Goodreads Choi...  978-1471403989
# 55203  We Were Liars: Winner of the YA Goodreads Choi...  978-1471403989
# 55204  We Were Liars: Winner of the YA Goodreads Choi...  978-1471403989
# 55205  We Were Liars: Winner of the YA Goodreads Choi...  978-1471403989
# 55206  We Were Liars: Winner of the YA Goodreads Choi...  978-1471403989
#
#                            Username Rating         Date  \
# 0                     Sonia Peruzzo      5  20 ago 2021
# 1                            Anto70      2  13 ago 2021
# 2                               mgt    4.5  22 lug 2021
# 3         La ragazza con la valigia      5  20 lug 2021
# 4                           Giorgia      5   8 giu 2021
# ...                             ...    ...          ...
# 55202                 Sheere Hikari      3   7 lug 2014
# 55203                  rogercastoro      3   6 lug 2014
# 55204                        missf.      4   4 lug 2014
# 55205          Alessandra Angeletti      4   4 lug 2014
# 55206  Laurina-la-fangirl-assassina      3  21 giu 2014
#
#                                             Review_Title  \
# 0                                Dire perfetto è troppo?
# 1                         Carino e leggero, forse troppo
# 2
# 3                             Edizione Minalima stupenda
# 4
# ...                                                  ...
# 55202
# 55203                          Fai ciò di cui hai paura.
# 55204
# 55205
# 55206  We are liars. We are beautiful and privileged....
#
#                                           Review_Content
# 0      Questo libro ha lanciato la mia fantasia da ra...
# 1      Carino, ma è uno dei pochi casi in cui la scen...
# 2      Ritirato fuori ieri. Magia, magia. Forse anche...
# 3      Questo volume da collezione è magnifico, veste...
# 4      Rileggere questo gioiello con le illustrazioni...
# ...                                                  ...
# 55202  In realtà più due e mezzo che tre stelline. No...
# 55203  diariodiunadipendenza.blogspot.it/2014/07/rece...
# 55204          mah.. secondo me,inutilmente angosciante.
# 55205  L'estate dei segreti perduti di E. Lockhart  u...
# 55206  I won't tell you the plot of this book. It is ...
#
# [55095 rows x 7 columns]

# %%
#analisi no vote per il rating, giusto per vedere quanti fossero

# %%
anobii_fin[anobii_fin['Rating']=='no_vote']  #i no vote del rating sno solo 3500 su 55k
# Out:
#                                                    Title            ISBN  \
# 9      Harry Potter e la pietra filosofale Tascabile ...  978-8831003384
# 19     Harry Potter e la pietra filosofale Tascabile ...  978-8831003384
# 48     Harry Potter e la pietra filosofale Tascabile ...  978-8831003384
# 49     Harry Potter e la pietra filosofale Tascabile ...  978-8831003384
# 58     Harry Potter e la pietra filosofale Tascabile ...  978-8831003384
# ...                                                  ...             ...
# 55083                                 La casa delle voci  978-8830448292
# 55103                                 La casa delle voci  978-8830448292
# 55133                                    Sangue Inquieto  978-8831005920
# 55143                                    Sangue Inquieto  978-8831005920
# 55198  We Were Liars: Winner of the YA Goodreads Choi...  978-1471403989
#
#                Username   Rating         Date  \
# 9          Chiara White  no_vote   5 gen 2021
# 19      Storione Saggio  no_vote  16 ott 2020
# 48     Attilio Facchini  no_vote   1 giu 2019
# 49               Winnie  no_vote  29 mag 2019
# 58           solosilvia  no_vote  21 ott 2018
# ...                 ...      ...          ...
# 55083               Ale  no_vote  21 feb 2020
# 55103        Mauriziods  no_vote   3 gen 2020
# 55133        acquolina1  no_vote  11 giu 2021
# 55143     Linda Car1969  no_vote  26 mar 2021
# 55198                美咲  no_vote  17 lug 2014
#
#                                          Review_Title  \
# 9
# 19     Il peggiore della saga, figuriamoci gli altri!
# 48
# 49
# 58                                               null
# ...                                               ...
# 55083
# 55103                              Bentornato maestro
# 55133     Non è solo un libro giallo ma molto di più
# 55143
# 55198
#
#                                           Review_Content
# 9      Mi ero ripromessa con il nuovo anno di rilegge...
# 19     facebook.com/maurizio.sacchi.99/posts/94632535...
# 48     Ed eccoci giunti a Harry Potter. Sì, finalment...
# 49     Libro fantastico. Magia e peripezie a più non ...
# 58     Seconda lettura, questa volra in digitale, a d...
# ...                                                  ...
# 55083  Non è il solito romanzo di Carrisi...vero. Ma ...
# 55103  Inizierei con un: “Bentornato, Maestro!”Rispet...
# 55133  Appena l'ho finito mi sono sentita triste e vu...
# 55143  Brava la signora, anche troppo. Il giallo è mo...
# 55198  Sono davvero indecisa; a tratti sembrava uno s...
#
# [3477 rows x 7 columns]

# %%
#export
anobii_fin.to_csv('anobii_reviewsIT.csv')

# %%
#lista titoli tenuti
import pandas as pd
anobii_fin=pd.read_csv("C:\\Users\\aless\\OneDrive\\Desktop\\Laurea_magistrale\\Tesi\\Dati\\Dati_Italia\\anobii_reviewsIT.csv")
anobii_fin
# Out:
#        Unnamed: 0                                              Title  \
# 0               0  Harry Potter e la pietra filosofale Tascabile ...
# 1               1  Harry Potter e la pietra filosofale Tascabile ...
# 2               2  Harry Potter e la pietra filosofale Tascabile ...
# 3               3  Harry Potter e la pietra filosofale Tascabile ...
# 4               4  Harry Potter e la pietra filosofale Tascabile ...
# ...           ...                                                ...
# 55090       55202  We Were Liars: Winner of the YA Goodreads Choi...
# 55091       55203  We Were Liars: Winner of the YA Goodreads Choi...
# 55092       55204  We Were Liars: Winner of the YA Goodreads Choi...
# 55093       55205  We Were Liars: Winner of the YA Goodreads Choi...
# 55094       55206  We Were Liars: Winner of the YA Goodreads Choi...
#
#                  ISBN                      Username Rating         Date  \
# 0      978-8831003384                 Sonia Peruzzo      5  20 ago 2021
# 1      978-8831003384                        Anto70      2  13 ago 2021
# 2      978-8831003384                           mgt    4.5  22 lug 2021
# 3      978-8831003384     La ragazza con la valigia      5  20 lug 2021
# 4      978-8831003384                       Giorgia      5   8 giu 2021
# ...               ...                           ...    ...          ...
# 55090  978-1471403989                 Sheere Hikari      3   7 lug 2014
# 55091  978-1471403989                  rogercastoro      3   6 lug 2014
# 55092  978-1471403989                        missf.      4   4 lug 2014
# 55093  978-1471403989          Alessandra Angeletti      4   4 lug 2014
# 55094  978-1471403989  Laurina-la-fangirl-assassina      3  21 giu 2014
#
#                                             Review_Title  \
# 0                                Dire perfetto è troppo?
# 1                         Carino e leggero, forse troppo
# 2                                                    NaN
# 3                             Edizione Minalima stupenda
# 4                                                    NaN
# ...                                                  ...
# 55090                                                NaN
# 55091                          Fai ciò di cui hai paura.
# 55092                                                NaN
# 55093                                                NaN
# 55094  We are liars. We are beautiful and privileged....
#
#                                           Review_Content
# 0      Questo libro ha lanciato la mia fantasia da ra...
# 1      Carino, ma è uno dei pochi casi in cui la scen...
# 2      Ritirato fuori ieri. Magia, magia. Forse anche...
# 3      Questo volume da collezione è magnifico, veste...
# 4      Rileggere questo gioiello con le illustrazioni...
# ...                                                  ...
# 55090  In realtà più due e mezzo che tre stelline. No...
# 55091  diariodiunadipendenza.blogspot.it/2014/07/rece...
# 55092          mah.. secondo me,inutilmente angosciante.
# 55093  L'estate dei segreti perduti di E. Lockhart  u...
# 55094  I won't tell you the plot of this book. It is ...
#
# [55095 rows x 8 columns]

# %%
#check di quante reviews italiane ci sono

lan=[]
import nltk
from textblob import TextBlob
for index,row in anobii_fin.iterrows():
    b = TextBlob(str(row['Review_Content']))
    try:
        lan.append(b.detect_language())
    except:
        lan.append('not found')
len(lan)
# Out:
# 55095

# %%
x=0
ind=[]
for el in anobii_fin['Review_Content']:
    if type(el) is not str:
        ind.append(x)
        #print(el)
    x+=1
len(ind)
# Out:
# 787

# %%
anobii_fin[anobii_fin['Review_Content'] != 'nan']
# Out:
#        Unnamed: 0                                              Title  \
# 0               0  Harry Potter e la pietra filosofale Tascabile ...
# 1               1  Harry Potter e la pietra filosofale Tascabile ...
# 2               2  Harry Potter e la pietra filosofale Tascabile ...
# 3               3  Harry Potter e la pietra filosofale Tascabile ...
# 4               4  Harry Potter e la pietra filosofale Tascabile ...
# ...           ...                                                ...
# 55090       55202  We Were Liars: Winner of the YA Goodreads Choi...
# 55091       55203  We Were Liars: Winner of the YA Goodreads Choi...
# 55092       55204  We Were Liars: Winner of the YA Goodreads Choi...
# 55093       55205  We Were Liars: Winner of the YA Goodreads Choi...
# 55094       55206  We Were Liars: Winner of the YA Goodreads Choi...
#
#                  ISBN                      Username Rating         Date  \
# 0      978-8831003384                 Sonia Peruzzo      5  20 ago 2021
# 1      978-8831003384                        Anto70      2  13 ago 2021
# 2      978-8831003384                           mgt    4.5  22 lug 2021
# 3      978-8831003384     La ragazza con la valigia      5  20 lug 2021
# 4      978-8831003384                       Giorgia      5   8 giu 2021
# ...               ...                           ...    ...          ...
# 55090  978-1471403989                 Sheere Hikari      3   7 lug 2014
# 55091  978-1471403989                  rogercastoro      3   6 lug 2014
# 55092  978-1471403989                        missf.      4   4 lug 2014
# 55093  978-1471403989          Alessandra Angeletti      4   4 lug 2014
# 55094  978-1471403989  Laurina-la-fangirl-assassina      3  21 giu 2014
#
#                                             Review_Title  \
# 0                                Dire perfetto è troppo?
# 1                         Carino e leggero, forse troppo
# 2                                                    NaN
# 3                             Edizione Minalima stupenda
# 4                                                    NaN
# ...                                                  ...
# 55090                                                NaN
# 55091                          Fai ciò di cui hai paura.
# 55092                                                NaN
# 55093                                                NaN
# 55094  We are liars. We are beautiful and privileged....
#
#                                           Review_Content
# 0      Questo libro ha lanciato la mia fantasia da ra...
# 1      Carino, ma è uno dei pochi casi in cui la scen...
# 2      Ritirato fuori ieri. Magia, magia. Forse anche...
# 3      Questo volume da collezione è magnifico, veste...
# 4      Rileggere questo gioiello con le illustrazioni...
# ...                                                  ...
# 55090  In realtà più due e mezzo che tre stelline. No...
# 55091  diariodiunadipendenza.blogspot.it/2014/07/rece...
# 55092          mah.. secondo me,inutilmente angosciante.
# 55093  L'estate dei segreti perduti di E. Lockhart  u...
# 55094  I won't tell you the plot of this book. It is ...
#
# [55095 rows x 8 columns]

# %%
from langdetect import detect
lang=[]
for index, row in anobii_fin['Review_Content'].iteritems():
    try:
        language = detect(row) #detecting each row
        lang.append(language)
    except:
        lang.append('not found')
lang
# Out:
# ['it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'ca',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'en',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'en',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'en',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'not found',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'not found',
#  'it',
#  'not found',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'not found',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'not found',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'ca',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'not found',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'not found',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'en',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'de',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  'it',
#  ...]

# %%
len(lang)
# Out:
# 55095

# %%
anobii_fin['Language']=lang
anobii_fin
# Out:
#        Unnamed: 0                                              Title  \
# 0               0  Harry Potter e la pietra filosofale Tascabile ...
# 1               1  Harry Potter e la pietra filosofale Tascabile ...
# 2               2  Harry Potter e la pietra filosofale Tascabile ...
# 3               3  Harry Potter e la pietra filosofale Tascabile ...
# 4               4  Harry Potter e la pietra filosofale Tascabile ...
# ...           ...                                                ...
# 55090       55202  We Were Liars: Winner of the YA Goodreads Choi...
# 55091       55203  We Were Liars: Winner of the YA Goodreads Choi...
# 55092       55204  We Were Liars: Winner of the YA Goodreads Choi...
# 55093       55205  We Were Liars: Winner of the YA Goodreads Choi...
# 55094       55206  We Were Liars: Winner of the YA Goodreads Choi...
#
#                  ISBN                      Username Rating         Date  \
# 0      978-8831003384                 Sonia Peruzzo      5  20 ago 2021
# 1      978-8831003384                        Anto70      2  13 ago 2021
# 2      978-8831003384                           mgt    4.5  22 lug 2021
# 3      978-8831003384     La ragazza con la valigia      5  20 lug 2021
# 4      978-8831003384                       Giorgia      5   8 giu 2021
# ...               ...                           ...    ...          ...
# 55090  978-1471403989                 Sheere Hikari      3   7 lug 2014
# 55091  978-1471403989                  rogercastoro      3   6 lug 2014
# 55092  978-1471403989                        missf.      4   4 lug 2014
# 55093  978-1471403989          Alessandra Angeletti      4   4 lug 2014
# 55094  978-1471403989  Laurina-la-fangirl-assassina      3  21 giu 2014
#
#                                             Review_Title  \
# 0                                Dire perfetto è troppo?
# 1                         Carino e leggero, forse troppo
# 2                                                    NaN
# 3                             Edizione Minalima stupenda
# 4                                                    NaN
# ...                                                  ...
# 55090                                                NaN
# 55091                          Fai ciò di cui hai paura.
# 55092                                                NaN
# 55093                                                NaN
# 55094  We are liars. We are beautiful and privileged....
#
#                                           Review_Content Language
# 0      Questo libro ha lanciato la mia fantasia da ra...       it
# 1      Carino, ma è uno dei pochi casi in cui la scen...       it
# 2      Ritirato fuori ieri. Magia, magia. Forse anche...       it
# 3      Questo volume da collezione è magnifico, veste...       it
# 4      Rileggere questo gioiello con le illustrazioni...       it
# ...                                                  ...      ...
# 55090  In realtà più due e mezzo che tre stelline. No...       it
# 55091  diariodiunadipendenza.blogspot.it/2014/07/rece...       it
# 55092          mah.. secondo me,inutilmente angosciante.       it
# 55093  L'estate dei segreti perduti di E. Lockhart  u...       it
# 55094  I won't tell you the plot of this book. It is ...       en
#
# [55095 rows x 9 columns]

# %%
anobii_itarev=anobii_fin[anobii_fin['Language'] == 'it']
anobii_itarev.to_csv('anobii_itarev.csv')
