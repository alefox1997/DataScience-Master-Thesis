# %%
import re
import time
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
PATH='C:\\Users\\aless\\OneDrive\\Desktop\\Laurea_magistrale\\Tesi\\chromedriver.exe'
driver = webdriver.Chrome(PATH)

# %%
import pandas as pd
meta_en=pd.read_csv("C:\\Users\\aless\\OneDrive\\Desktop\\Laurea_magistrale\\Tesi\\Dati\\Dati_English\\metadati_EN.csv")
meta_en
# Out:
#      Unnamed: 0  index        Genere  \
# 0             0      0  Children_Lit
# 1             1      1  Children_Lit
# 2             2      2  Children_Lit
# 3             3      3  Children_Lit
# 4             4      4  Children_Lit
# ..          ...    ...           ...
# 995         995   1063         Scify
# 996         996   1064         Scify
# 997         997   1065         Scify
# 998         998   1066         Scify
# 999         999   1067         Scify
#
#                                       Genere_Suggerito  \
# 0    ['Childrens\n4,244 users', 'Childrens > Pictur...
# 1    ['Childrens\n4,125 users', 'Childrens > Pictur...
# 2    ['Childrens\n3,957 users', 'Fiction\n3,617 use...
# 3    ['Classics\n18,253 users', 'Fiction\n5,704 use...
# 4    ['Childrens\n3,071 users', 'Fantasy\n2,796 use...
# ..                                                 ...
# 995  ['Science Fiction\n1,076 users', 'Fiction\n508...
# 996  ['Science Fiction\n1,069 users', 'Fiction\n357...
# 997  ['Science Fiction\n1,066 users', 'Fiction\n1,0...
# 998  ['Science Fiction\n1,065 users', 'Fiction\n410...
# 999  ['Science Fiction\n1,058 users', 'Fiction\n227...
#
#                                               Pud_Data  \
# 0    Published 2000 by Red Fox (first published Apr...
# 1    Published October 7th 1964 by HarperCollins Pu...
# 2    Published June 1st 1998 by Puffin Books (first...
# 3    Published September 1st 1998 by Children's Cla...
# 4    Published September 10th 2002 by Alfred A. Kno...
# ..                                                 ...
# 995  Published December 1997 by Spectra/Bantam Book...
# 996  Published January 15th 2000 by Tor Science Fic...
# 997  Published December 5th 2005 by HarperCollins P...
# 998                   Published July 7th 2015 by Orbit
# 999  Published May 14th 2013 by Tor Books (first pu...
#
#                          Title                   Author           ISBN  \
# 0    Where the Wild Things Are           Maurice Sendak  9780099408390
# 1              The Giving Tree         Shel Silverstein  9780060256654
# 2                      Matilda               Roald Dahl  9780141301068
# 3            The Secret Garden  Frances Hodgson Burnett  9780517189603
# 4    James and the Giant Peach               Roald Dahl  9780375814242
# ..                         ...                      ...            ...
# 995                The Postman               David Brin  9780553278743
# 996      A Deepness in the Sky             Vernor Vinge  9780812536355
# 997      That Hideous Strength               C.S. Lewis  9780007157174
# 998                     Aurora     Kim Stanley Robinson  9780316098106
# 999         The Human Division              John Scalzi  9780765333513
#
#     Num_Pages_GR  Stars_GR                       Distr_Rat_GR  N_Votes_GR  \
# 0             38      4.22  ['53%', '25%', '14%', '5%', '3%']      884675
# 1             64      4.37  ['61%', '22%', '10%', '3%', '3%']      978948
# 2            240      4.32  ['53%', '31%', '13%', '2%', '1%']      741229
# 3            331      4.13  ['43%', '34%', '17%', '4%', '2%']      984296
# 4            146      4.01  ['38%', '34%', '21%', '5%', '2%']      414915
# ..           ...       ...                                ...         ...
# 995          321      3.90  ['29%', '40%', '24%', '5%', '2%']       34029
# 996          775      4.30  ['50%', '34%', '12%', '3%', '1%']       31799
# 997          534      3.88  ['34%', '33%', '23%', '7%', '3%']       34925
# 998          466      3.76  ['25%', '40%', '24%', '8%', '3%']       23091
# 999          431      4.07  ['34%', '45%', '17%', '3%', '1%']       30718
#
#      N_Reviews_GR                                            GR_link  \
# 0           12480  https://www.goodreads.com/book/show/19543.Wher...
# 1           19120  https://www.goodreads.com/book/show/370493.The...
# 2           18376  https://www.goodreads.com/book/show/39988.Matilda
# 3           21409  https://www.goodreads.com/book/show/2998.The_S...
# 4            7540  https://www.goodreads.com/book/show/6689.James...
# ..            ...                                                ...
# 995          1387  https://www.goodreads.com/book/show/889284.The...
# 996          1075  https://www.goodreads.com/book/show/226004.A_D...
# 997          2091  https://www.goodreads.com/book/show/100933.Tha...
# 998          2709  https://www.goodreads.com/book/show/23197269-a...
# 999          1615  https://www.goodreads.com/book/show/15698479-t...
#
#      Stars_AZ                       Distr_Rat_AZ  N_Votes_AZ  N_Reviews_AZ  \
# 0         4.9    ['92%', '5%', '2%', '1%', '1%']     23220.0        3003.0
# 1         4.9    ['92%', '5%', '2%', '1%', '1%']     18132.0        3463.0
# 2         4.8    ['86%', '9%', '3%', '1%', '1%']      5422.0        1160.0
# 3         4.6   ['78%', '13%', '5%', '2%', '3%']      8946.0        2478.0
# 4         4.8    ['85%', '9%', '3%', '1%', '2%']      4101.0         838.0
# ..        ...                                ...         ...           ...
# 995       4.4   ['64%', '22%', '9%', '3%', '2%']       670.0         266.0
# 996       4.6   ['72%', '18%', '6%', '3%', '1%']       458.0         228.0
# 997       4.7   ['79%', '12%', '5%', '2%', '1%']       800.0         320.0
# 998       3.9  ['40%', '29%', '16%', '9%', '5%']      1353.0         769.0
# 999       4.4   ['59%', '28%', '9%', '3%', '2%']      1151.0         563.0
#
#                                                AZ_link
# 0    https://www.amazon.it/s?k=9780099408390&i=stri...
# 1    https://www.amazon.it/s?k=9780060256654&i=stri...
# 2    https://www.amazon.it/s?k=9780141301068&i=stri...
# 3    https://www.amazon.it/s?k=9780517189603&i=stri...
# 4    https://www.amazon.it/s?k=9780375814242&i=stri...
# ..                                                 ...
# 995  https://www.amazon.it/s?k=9780553278743&i=stri...
# 996  https://www.amazon.it/s?k=9780812536355&i=stri...
# 997  https://www.amazon.it/s?k=9780007157174&i=stri...
# 998  https://www.amazon.it/s?k=9780316098106&i=stri...
# 999  https://www.amazon.it/s?k=9780765333513&i=stri...
#
# [1000 rows x 19 columns]

# %%
isbn=meta_en['ISBN'].to_list()
title=meta_en['Title'].to_list()
gen=meta_en['Genere'].to_list()
mylinks=meta_en['GR_link'].to_list()
print(isbn[:10])
print(title[:10])
print(gen[:10])
print(mylinks[:10])
# Out:
# [9780099408390, 9780060256654, 9780141301068, 9780517189603, 9780375814242, 9780241003008, 9780141311371, 9780060775858, 9780590032490, 9780439206471]
# ['Where the Wild Things Are', 'The Giving Tree', 'Matilda', 'The Secret Garden', 'James and the Giant Peach', 'The Very Hungry Caterpillar', 'The BFG', 'Goodnight Moon', 'The Witches', 'The Bad Beginning']
# ['Children_Lit', 'Children_Lit', 'Children_Lit', 'Children_Lit', 'Children_Lit', 'Children_Lit', 'Children_Lit', 'Children_Lit', 'Children_Lit', 'Children_Lit']
# ['https://www.goodreads.com/book/show/19543.Where_the_Wild_Things_Are', 'https://www.goodreads.com/book/show/370493.The_Giving_Tree', 'https://www.goodreads.com/book/show/39988.Matilda', 'https://www.goodreads.com/book/show/2998.The_Secret_Garden', 'https://www.goodreads.com/book/show/6689.James_and_the_Giant_Peach', 'https://www.goodreads.com/book/show/4948.The_Very_Hungry_Caterpillar', 'https://www.goodreads.com/book/show/6319.The_BFG', 'https://www.goodreads.com/book/show/32929.Goodnight_Moon', 'https://www.goodreads.com/book/show/6327.The_Witches', 'https://www.goodreads.com/book/show/78411.The_Bad_Beginning']

# %%
#controlla se ci sono libri che hanno meno di 300 reviews per goodreads. Se si, devi gestire le lioste dentro al ciclo di cattura. Se no, puoi crearle ad hoc con il codice sottostante

# %%
#pagina order: newest
def switch_reviews_mode(driver, book_id, sort_order, rating=''):
    """
    Copyright (C) 2019 by Omar Einea: https://github.com/OmarEinea/GoodReadsScraper
    Licensed under GPL v3.0: https://github.com/OmarEinea/GoodReadsScraper/blob/master/LICENSE.md
    Accessed on 2019-12-01.
    """
    edition_reviews=False
    driver.execute_script(
        'document.getElementById("reviews").insertAdjacentHTML("beforeend", \'<a data-remote="true" rel="nofollow"'
        f'class="actionLinkLite loadingLink" data-keep-on-success="true" id="switch{rating}{sort_order}"' +
        f'href="/book/reviews/{book_id}?rating={rating}&sort={sort_order}' +
        ('&edition_reviews=true' if edition_reviews else '') + '">Switch Mode</a>\');' +
        f'document.getElementById("switch{rating}{sort_order}").click()'
    )
    return True

# %%
titoli=[]
isbn_code=[]
genere=[]
#metadata reviews

userlist=[]
ratings=[]
rev_date=[]
shelves=[]
n_likes=[]
rev_content=[]

# %%
from selenium.webdriver.support.ui import Select
number=-1
sort_order='newest'
for lnk in mylinks[:100]:  #riporta a zero poi
    number+=1  #teniamo conto di quanto siamo arrivati a livello di conteggio per gestire eventuali ripartenze
        
    try:
        try:
            time.sleep(2)
            driver.get(lnk)  #e sei già alla prima pagina di reviews. per ogni pagina abbiamo 30 reviews
        except:
            time.sleep(5)
            driver.get(lnk)
    except:
        userlist.extend(['error' for x in range(30)])
        ratings.extend(['error' for x in range(30)])
        rev_date.extend(['error' for x in range(30)])
        shelves.extend(['error' for x in range(30)])
        n_likes.extend(['error' for x in range(30)])
        rev_content.extend(['error' for x in range(30)])
        titoli.extend([title[number] for x in range(30)])
        isbn_code.extend([isbn[number] for x in range(30)])
        genere.extend([gen[number] for x in range(30)])
        continue
                    
    
    #english - newest
    
    bandiera=0
    try:
        try:
            time.sleep(1)
            book_id=lnk.split("/")[-1] 
            switch_reviews_mode(driver, book_id, sort_order)
            time.sleep(4)
            select = Select(driver.find_element_by_name('language_code'))
            select.select_by_value('en')
            time.sleep(1)
            bandiera+=1
        except:
            time.sleep(5)
            driver.get(lnk)  #rieffettui l'operazione
            book_id=lnk.split("/")[-1] 
            switch_reviews_mode(driver, book_id, sort_order)
            time.sleep(4)
            select = Select(driver.find_element_by_name('language_code'))
            select.select_by_value('en')
            time.sleep(1)
            bandiera+=1
            
    except:
            userlist.extend(['error' for x in range(30)])
            ratings.extend(['error' for x in range(30)])
            rev_date.extend(['error' for x in range(30)])
            shelves.extend(['error' for x in range(30)])
            n_likes.extend(['error' for x in range(30)])
            rev_content.extend(['error' for x in range(30)])
            titoli.extend([title[number] for x in range(30)])
            isbn_code.extend([isbn[number] for x in range(30)])
            genere.extend([gen[number] for x in range(30)])
    
    #PER LA PRIMA PAGINA:
    
    try:
        try:
            time.sleep(3)
            li_reviews=driver.find_elements_by_xpath("//div[@id='bookReviews']/div[@class='friendReviews elementListBrown']")
            if len(li_reviews)==0:
                time.sleep(2)
                li_reviews=driver.find_elements_by_xpath("//div[@id='bookReviews']/div[@class='friendReviews elementListBrown']")
        except:
            time.sleep(5)
            li_reviews=driver.find_elements_by_xpath("//div[@id='bookReviews']/div[@class='friendReviews elementListBrown']") 
    except:
        userlist.extend(['error' for x in range(30)])
        ratings.extend(['error' for x in range(30)])
        rev_date.extend(['error' for x in range(30)])
        shelves.extend(['error' for x in range(30)])
        n_likes.extend(['error' for x in range(30)])
        rev_content.extend(['error' for x in range(30)])
        titoli.extend([title[number] for x in range(30)])
        isbn_code.extend([isbn[number] for x in range(30)])
        genere.extend([gen[number] for x in range(30)])
        continue
                    
                
    #accediamo dunque ai metadati delle recensioni:
                
    #creiamo prima la lista degli id
                
    id_rev=[]    #lista id per la pagina
    try:
        try:
            time.sleep(3)
            ids=li_reviews[0].find_elements_by_xpath("//div/div[@itemprop='reviews']")
            if len(ids)==0:
                time.sleep(1)
                ids=li_reviews[0].find_elements_by_xpath("//div/div[@itemprop='reviews']")
        except:
            time.sleep(5)
            ids=li_reviews[0].find_elements_by_xpath("//div/div[@itemprop='reviews']")
    except:
        userlist.extend(['error' for x in range(30)])
        ratings.extend(['error' for x in range(30)])
        rev_date.extend(['error' for x in range(30)])
        shelves.extend(['error' for x in range(30)])
        n_likes.extend(['error' for x in range(30)])
        rev_content.extend(['error' for x in range(30)])
        titoli.extend([title[number] for x in range(30)])
        isbn_code.extend([isbn[number] for x in range(30)])
        genere.extend([gen[number] for x in range(30)])
        continue
                    
                    
    for el in ids:
        
        try:
            time.sleep(2)
            id_rev.append(el.get_attribute('id'))
        except:
            userlist.append('error')
            ratings.append('error')
            rev_date.append('error')
            shelves.append('error')
            n_likes.append('error')
            rev_content.append('error')
            titoli.append(title[number])
            isbn_code.append(isbn[number])
            genere.append(gen[number])
            continue
    
    for elem in id_rev:
        
        titoli.append(title[number])
        isbn_code.append(isbn[number])
        genere.append(gen[number])
    
        #user
        try:
            user=driver.find_element_by_xpath("//div[@id='"+str(elem)+"']/a").get_attribute('title')
            userlist.append(user)
        except:
            userlist.append('error')
    
            #review date
        try:
            dat=driver.find_element_by_xpath("//div[@id='"+str(elem)+"']/div[@class='left bodycol']/div/a").get_attribute('textContent')
            rev_date.append(dat)
        except:
            rev_date.append('error')
    
            #ratings
        time.sleep(1)
        try:
            rat=driver.find_elements_by_xpath("//div[@id='"+str(elem)+"']/div[@class='left bodycol']/div/span")[1].get_attribute('title')
            if str(rat) == 'did not like it':
                ratings.append(1)
            if str(rat) == 'it was ok':
                ratings.append(2)
            if str(rat) == 'liked it':
                ratings.append(3)
            if str(rat) == 'really liked it':
                ratings.append(4)
            if str(rat) == 'it was amazing':
                ratings.append(5)
            if str(rat) == '':
                ratings.append('error')
        except:
            ratings.append('error')
                        
                    
                    #shelves
        try:
            she=driver.find_elements_by_xpath("//div[@id='"+str(elem)+"']/div[@class='left bodycol']/div/div[@class='uitext greyText bookshelves']/a")
            aus_she=[]
            for el in she:
                aus_she.append(el.text)
            shelves.append(aus_she)
        except:
            shelves.append('error')
                        
            #likes
                    
        try:
            like=driver.find_element_by_xpath("//div[@id='"+str(elem)+"']/div[@class='left bodycol']/div[@class='reviewFooter uitext buttons']/div/span/a").text
            n_like=int(re.findall(r'\d+' ,like)[0])
            n_likes.append(n_like)
        except:
            n_likes.append('error')
        
    
        #content review
        try:
            try:
                time.sleep(2)
                cont=driver.find_elements_by_xpath("//div[@id='"+str(elem)+"']/div[@class='left bodycol']/div[@class='reviewText stacked']/span/span")[1]
                rev_content.append(cont.get_attribute('textContent'))  
            except:
                time.sleep(4)
                cont=driver.find_element_by_xpath("//div[@id='"+str(elem)+"']/div[@class='left bodycol']/div[@class='reviewText stacked']/span/span")
                rev_content.append(cont.get_attribute('textContent')) 
        except:
            rev_content.append('error')
        
    
 
    #DALLA SECONDA PAGINA IN POI     
            
    for i in range(2,11,1): #30 pagine da 30 reviews, totale 300
                
        try:
            try:
                time.sleep(1)
                driver.find_element_by_link_text(str(i)).click()
            except:
                time.sleep(5)
                driver.find_element_by_link_text(str(i)).click()
        except:
            userlist.extend(['error' for x in range(30)])
            ratings.extend(['error' for x in range(30)])
            rev_date.extend(['error' for x in range(30)])
            shelves.extend(['error' for x in range(30)])
            n_likes.extend(['error' for x in range(30)])
            rev_content.extend(['error' for x in range(30)])
            titoli.extend([title[number] for x in range(30)])
            isbn_code.extend([isbn[number] for x in range(30)])
            genere.extend([gen[number] for x in range(30)])
            continue
                    
        if bandiera==0:
            try:
                try:
                    book_id=lnk.split("/")[-1] 
                    switch_reviews_mode(driver, book_id, sort_order)
                    time.sleep(4)
                    select = Select(driver.find_element_by_name('language_code'))
                    select.select_by_value('en')
                    time.sleep(1)
            
                except:
                    driver.get(lnk)  #rieffettui l'operazione
                    book_id=lnk.split("/")[-1] 
                    switch_reviews_mode(driver, book_id, sort_order)
                    time.sleep(4)
                    select = Select(driver.find_element_by_name('language_code'))
                    select.select_by_value('en')
                    time.sleep(1)
            
            except:
                userlist.extend(['error' for x in range(270)])
                ratings.extend(['error' for x in range(270)])
                rev_date.extend(['error' for x in range(270)])
                shelves.extend(['error' for x in range(270)])
                n_likes.extend(['error' for x in range(270)])
                rev_content.extend(['error' for x in range(270)])
                titoli.extend([title[number] for x in range(270)])
                isbn_code.extend([isbn[number] for x in range(270)])
                genere.extend([gen[number] for x in range(270)])
                        

                    
                    
                
        try:
                try:
                    time.sleep(3)
                    li_reviews=driver.find_elements_by_xpath("//div[@id='bookReviews']/div[@class='friendReviews elementListBrown']")
                    if len(li_reviews)==0:
                        time.sleep(2)
                        li_reviews=driver.find_elements_by_xpath("//div[@id='bookReviews']/div[@class='friendReviews elementListBrown']")
                except:
                    time.sleep(5)
                    li_reviews=driver.find_elements_by_xpath("//div[@id='bookReviews']/div[@class='friendReviews elementListBrown']") 
        except:
                userlist.extend(['error' for x in range(30)])
                ratings.extend(['error' for x in range(30)])
                rev_date.extend(['error' for x in range(30)])
                shelves.extend(['error' for x in range(30)])
                n_likes.extend(['error' for x in range(30)])
                rev_content.extend(['error' for x in range(30)])
                titoli.extend([title[number] for x in range(30)])
                isbn_code.extend([isbn[number] for x in range(30)])
                genere.extend([gen[number] for x in range(30)])
                continue
                    
                
                #accediamo dunque ai metadati delle recensioni:
                
                #creiamo prima la lista degli id
                
        id_rev=[]    #lista id per la pagina
        try:
                try:
                    time.sleep(3)
                    ids=li_reviews[0].find_elements_by_xpath("//div/div[@itemprop='reviews']")
                    if len(ids)==0:
                        time.sleep(2)
                        ids=li_reviews[0].find_elements_by_xpath("//div/div[@itemprop='reviews']")
                except:
                    time.sleep(5)
                    ids=li_reviews[0].find_elements_by_xpath("//div/div[@itemprop='reviews']")
        except:
                userlist.extend(['error' for x in range(30)])
                ratings.extend(['error' for x in range(30)])
                rev_date.extend(['error' for x in range(30)])
                shelves.extend(['error' for x in range(30)])
                n_likes.extend(['error' for x in range(30)])
                rev_content.extend(['error' for x in range(30)])
                titoli.extend([title[number] for x in range(30)])
                isbn_code.extend([isbn[number] for x in range(30)])
                genere.extend([gen[number] for x in range(30)])
                continue
                    
                    
        for el in ids:

            try:
                    time.sleep(2)
                    id_rev.append(el.get_attribute('id'))
            except:
                    userlist.append('error')
                    ratings.append('error')
                    rev_date.append('error')
                    shelves.append('error')
                    n_likes.append('error')
                    rev_content.append('error')
                    titoli.append(title[number])
                    isbn_code.append(isbn[number])
                    genere.append(gen[number])
                    continue
    
        for elem in id_rev:
            
            titoli.append(title[number])
            isbn_code.append(isbn[number])
            genere.append(gen[number])
    
            #user
            try:
                    user=driver.find_element_by_xpath("//div[@id='"+str(elem)+"']/a").get_attribute('title')
                    userlist.append(user)
            except:
                    userlist.append('error')
    
                #review date
            try:
                    dat=driver.find_element_by_xpath("//div[@id='"+str(elem)+"']/div[@class='left bodycol']/div/a").get_attribute('textContent')
                    rev_date.append(dat)
            except:
                    rev_date.append('error')
    
                #ratings
            time.sleep(1)
            try:
                    rat=driver.find_elements_by_xpath("//div[@id='"+str(elem)+"']/div[@class='left bodycol']/div/span")[1].get_attribute('title')
                    if str(rat) == 'did not like it':
                        ratings.append(1)
                    if str(rat) == 'it was ok':
                        ratings.append(2)
                    if str(rat) == 'liked it':
                        ratings.append(3)
                    if str(rat) == 'really liked it':
                        ratings.append(4)
                    if str(rat) == 'it was amazing':
                        ratings.append(5)
                    if str(rat) == '':
                        ratings.append('error')
            except:
                    ratings.append('error')
                        
                    
                    #shelves
            try:
                    she=driver.find_elements_by_xpath("//div[@id='"+str(elem)+"']/div[@class='left bodycol']/div/div[@class='uitext greyText bookshelves']/a")
                    aus_she=[]
                    for el in she:
                        aus_she.append(el.text)
                    shelves.append(aus_she)
            except:
                    shelves.append('error')
                        
                    #likes
                    
            try:
                    like=driver.find_element_by_xpath("//div[@id='"+str(elem)+"']/div[@class='left bodycol']/div[@class='reviewFooter uitext buttons']/div/span/a").text
                    n_like=int(re.findall(r'\d+' ,like)[0])
                    n_likes.append(n_like)
            except:
                    n_likes.append('error')
        
    
                    #content review
            time.sleep(1)
            try:
                    try:
                        cont=driver.find_elements_by_xpath("//div[@id='"+str(elem)+"']/div[@class='left bodycol']/div[@class='reviewText stacked']/span/span")[1]
                        rev_content.append(cont.get_attribute('textContent'))  
                    except:
                        time.sleep(5)
                        cont=driver.find_element_by_xpath("//div[@id='"+str(elem)+"']/div[@class='left bodycol']/div[@class='reviewText stacked']/span/span")
                        rev_content.append(cont.get_attribute('textContent')) 
            except:
                        rev_content.append('error')
            
    
    
    print(number)
    print(len(rev_content))
    print(len(titoli))
    er=0
    for el in rev_content:
        if el=='error':
            er+=1
    print(er)
    print('\n')
    
    if len(rev_content) != len(titoli):   #per capire se ci sono problemi legati al raccoglimento dei ratings
        break

# %%
print(len(shelves))
print(len(n_likes))
print(len(userlist))
print(len(ratings))
print(len(rev_date))
print(len(rev_content))
# Out:
# 29986
# 29986
# 29986
# 29986
# 29986
# 29986

# %%
number
# Out:
# 99

# %%
shelves=shelves[:66900]
n_likes=n_likes[:66900]
userlist=userlist[:66900]
ratings=ratings[:66900]
rev_date=rev_date[:66900]
rev_content=rev_content[:66900]

# %%
Goodreads_Rev=pd.DataFrame(list(zip(titoli,isbn_code,genere,shelves,n_likes,userlist,ratings,rev_date,rev_content)),columns=['Titolo','ISBN','Genere','Shelves','N_Likes_GR','Userlist_GR','Rating_GR','Rev_Date_GR','Rev_Content_GR'])
Goodreads_Rev
# Out:
#                           Titolo           ISBN        Genere  \
# 0      Where the Wild Things Are  9780099408390  Children_Lit
# 1      Where the Wild Things Are  9780099408390  Children_Lit
# 2      Where the Wild Things Are  9780099408390  Children_Lit
# 3      Where the Wild Things Are  9780099408390  Children_Lit
# 4      Where the Wild Things Are  9780099408390  Children_Lit
# ...                          ...            ...           ...
# 29981                  Esio Trot  9780224064927  Children_Lit
# 29982                  Esio Trot  9780224064927  Children_Lit
# 29983                  Esio Trot  9780224064927  Children_Lit
# 29984                  Esio Trot  9780224064927  Children_Lit
# 29985                  Esio Trot  9780224064927  Children_Lit
#
#                       Shelves N_Likes_GR           Userlist_GR Rating_GR  \
# 0                          []      error  Kiera (Student Mode)     error
# 1      [library-media-course]      error                Sierra         5
# 2                          []      error    Destiney Cleveland         5
# 3         [40-book-challenge]      error        Grace Galloway         5
# 4                          []      error         Kaitlin Brame         5
# ...                       ...        ...                   ...       ...
# 29981                      []      error             Elisabeth         2
# 29982                      []      error            Taha Babar         4
# 29983                      []          1                Autumn         5
# 29984                      []      error               Jessica         5
# 29985                      []      error          Arbien White         2
#
#         Rev_Date_GR                                     Rev_Content_GR
# 0      Sep 27, 2021  \t\t “And now,” cried Max,\t\t\t“let the wild ...
# 1      Sep 26, 2021  I will always love this book. Through the most...
# 2      Sep 26, 2021  This story was one of my all-time favorite sto...
# 3      Sep 26, 2021  This was my favorite book as a child because o...
# 4      Sep 25, 2021  I am not going to lie, I have never, ever read...
# ...             ...                                                ...
# 29981  May 21, 2020  Deceit and trickery gets you what you want? A ...
# 29982  May 20, 2020  Interesting, funny. I liked how Mr. Hoppy got ...
# 29983  May 20, 2020  I enjoyed this book very much! I thought even ...
# 29984  May 16, 2020  Classic Dahl. It's funny, silly, cute and enjo...
# 29985  May 12, 2020  It’s a OK book but it’s quite short: Maybe 150...
#
# [29986 rows x 9 columns]

# %%
Goodreads_Rev2=Goodreads_Rev[Goodreads_Rev['Rev_Content_GR']!='error']
Goodreads_Rev2
# Out:
#                           Titolo           ISBN        Genere  \
# 0      Where the Wild Things Are  9780099408390  Children_Lit
# 1      Where the Wild Things Are  9780099408390  Children_Lit
# 2      Where the Wild Things Are  9780099408390  Children_Lit
# 3      Where the Wild Things Are  9780099408390  Children_Lit
# 4      Where the Wild Things Are  9780099408390  Children_Lit
# ...                          ...            ...           ...
# 29981                  Esio Trot  9780224064927  Children_Lit
# 29982                  Esio Trot  9780224064927  Children_Lit
# 29983                  Esio Trot  9780224064927  Children_Lit
# 29984                  Esio Trot  9780224064927  Children_Lit
# 29985                  Esio Trot  9780224064927  Children_Lit
#
#                       Shelves N_Likes_GR           Userlist_GR Rating_GR  \
# 0                          []      error  Kiera (Student Mode)     error
# 1      [library-media-course]      error                Sierra         5
# 2                          []      error    Destiney Cleveland         5
# 3         [40-book-challenge]      error        Grace Galloway         5
# 4                          []      error         Kaitlin Brame         5
# ...                       ...        ...                   ...       ...
# 29981                      []      error             Elisabeth         2
# 29982                      []      error            Taha Babar         4
# 29983                      []          1                Autumn         5
# 29984                      []      error               Jessica         5
# 29985                      []      error          Arbien White         2
#
#         Rev_Date_GR                                     Rev_Content_GR
# 0      Sep 27, 2021  \t\t “And now,” cried Max,\t\t\t“let the wild ...
# 1      Sep 26, 2021  I will always love this book. Through the most...
# 2      Sep 26, 2021  This story was one of my all-time favorite sto...
# 3      Sep 26, 2021  This was my favorite book as a child because o...
# 4      Sep 25, 2021  I am not going to lie, I have never, ever read...
# ...             ...                                                ...
# 29981  May 21, 2020  Deceit and trickery gets you what you want? A ...
# 29982  May 20, 2020  Interesting, funny. I liked how Mr. Hoppy got ...
# 29983  May 20, 2020  I enjoyed this book very much! I thought even ...
# 29984  May 16, 2020  Classic Dahl. It's funny, silly, cute and enjo...
# 29985  May 12, 2020  It’s a OK book but it’s quite short: Maybe 150...
#
# [20836 rows x 9 columns]

# %%
Goodreads_Rev2.to_csv('Goodreads_Rev_to100.csv') #nella cartella hai Goodreasd_Rev_to223, è un parziale di salvaguardia, in attesa del totale a 500

# %%
#disambiguazione genere del libro

# %%
import pandas as pd
meta=pd.read_csv("C:\\Users\\aless\\OneDrive\\Desktop\\Laurea_magistrale\\Tesi\\Dati\\Dati_English\\Metadati_EN.csv")
meta
# Out:
#      Unnamed: 0  index        Genere  \
# 0             0      0  Children_Lit
# 1             1      1  Children_Lit
# 2             2      2  Children_Lit
# 3             3      3  Children_Lit
# 4             4      4  Children_Lit
# ..          ...    ...           ...
# 995         995   1063         Scify
# 996         996   1064         Scify
# 997         997   1065         Scify
# 998         998   1066         Scify
# 999         999   1067         Scify
#
#                                       Genere_Suggerito  \
# 0    ['Childrens\n4,244 users', 'Childrens > Pictur...
# 1    ['Childrens\n4,125 users', 'Childrens > Pictur...
# 2    ['Childrens\n3,957 users', 'Fiction\n3,617 use...
# 3    ['Classics\n18,253 users', 'Fiction\n5,704 use...
# 4    ['Childrens\n3,071 users', 'Fantasy\n2,796 use...
# ..                                                 ...
# 995  ['Science Fiction\n1,076 users', 'Fiction\n508...
# 996  ['Science Fiction\n1,069 users', 'Fiction\n357...
# 997  ['Science Fiction\n1,066 users', 'Fiction\n1,0...
# 998  ['Science Fiction\n1,065 users', 'Fiction\n410...
# 999  ['Science Fiction\n1,058 users', 'Fiction\n227...
#
#                                               Pud_Data  \
# 0    Published 2000 by Red Fox (first published Apr...
# 1    Published October 7th 1964 by HarperCollins Pu...
# 2    Published June 1st 1998 by Puffin Books (first...
# 3    Published September 1st 1998 by Children's Cla...
# 4    Published September 10th 2002 by Alfred A. Kno...
# ..                                                 ...
# 995  Published December 1997 by Spectra/Bantam Book...
# 996  Published January 15th 2000 by Tor Science Fic...
# 997  Published December 5th 2005 by HarperCollins P...
# 998                   Published July 7th 2015 by Orbit
# 999  Published May 14th 2013 by Tor Books (first pu...
#
#                          Title                   Author           ISBN  \
# 0    Where the Wild Things Are           Maurice Sendak  9780099408390
# 1              The Giving Tree         Shel Silverstein  9780060256654
# 2                      Matilda               Roald Dahl  9780141301068
# 3            The Secret Garden  Frances Hodgson Burnett  9780517189603
# 4    James and the Giant Peach               Roald Dahl  9780375814242
# ..                         ...                      ...            ...
# 995                The Postman               David Brin  9780553278743
# 996      A Deepness in the Sky             Vernor Vinge  9780812536355
# 997      That Hideous Strength               C.S. Lewis  9780007157174
# 998                     Aurora     Kim Stanley Robinson  9780316098106
# 999         The Human Division              John Scalzi  9780765333513
#
#     Num_Pages_GR  Stars_GR                       Distr_Rat_GR  N_Votes_GR  \
# 0             38      4.22  ['53%', '25%', '14%', '5%', '3%']      884675
# 1             64      4.37  ['61%', '22%', '10%', '3%', '3%']      978948
# 2            240      4.32  ['53%', '31%', '13%', '2%', '1%']      741229
# 3            331      4.13  ['43%', '34%', '17%', '4%', '2%']      984296
# 4            146      4.01  ['38%', '34%', '21%', '5%', '2%']      414915
# ..           ...       ...                                ...         ...
# 995          321      3.90  ['29%', '40%', '24%', '5%', '2%']       34029
# 996          775      4.30  ['50%', '34%', '12%', '3%', '1%']       31799
# 997          534      3.88  ['34%', '33%', '23%', '7%', '3%']       34925
# 998          466      3.76  ['25%', '40%', '24%', '8%', '3%']       23091
# 999          431      4.07  ['34%', '45%', '17%', '3%', '1%']       30718
#
#      N_Reviews_GR                                            GR_link  \
# 0           12480  https://www.goodreads.com/book/show/19543.Wher...
# 1           19120  https://www.goodreads.com/book/show/370493.The...
# 2           18376  https://www.goodreads.com/book/show/39988.Matilda
# 3           21409  https://www.goodreads.com/book/show/2998.The_S...
# 4            7540  https://www.goodreads.com/book/show/6689.James...
# ..            ...                                                ...
# 995          1387  https://www.goodreads.com/book/show/889284.The...
# 996          1075  https://www.goodreads.com/book/show/226004.A_D...
# 997          2091  https://www.goodreads.com/book/show/100933.Tha...
# 998          2709  https://www.goodreads.com/book/show/23197269-a...
# 999          1615  https://www.goodreads.com/book/show/15698479-t...
#
#      Stars_AZ                       Distr_Rat_AZ  N_Votes_AZ  N_Reviews_AZ  \
# 0         4.9    ['92%', '5%', '2%', '1%', '1%']     23220.0        3003.0
# 1         4.9    ['92%', '5%', '2%', '1%', '1%']     18132.0        3463.0
# 2         4.8    ['86%', '9%', '3%', '1%', '1%']      5422.0        1160.0
# 3         4.6   ['78%', '13%', '5%', '2%', '3%']      8946.0        2478.0
# 4         4.8    ['85%', '9%', '3%', '1%', '2%']      4101.0         838.0
# ..        ...                                ...         ...           ...
# 995       4.4   ['64%', '22%', '9%', '3%', '2%']       670.0         266.0
# 996       4.6   ['72%', '18%', '6%', '3%', '1%']       458.0         228.0
# 997       4.7   ['79%', '12%', '5%', '2%', '1%']       800.0         320.0
# 998       3.9  ['40%', '29%', '16%', '9%', '5%']      1353.0         769.0
# 999       4.4   ['59%', '28%', '9%', '3%', '2%']      1151.0         563.0
#
#                                                AZ_link
# 0    https://www.amazon.it/s?k=9780099408390&i=stri...
# 1    https://www.amazon.it/s?k=9780060256654&i=stri...
# 2    https://www.amazon.it/s?k=9780141301068&i=stri...
# 3    https://www.amazon.it/s?k=9780517189603&i=stri...
# 4    https://www.amazon.it/s?k=9780375814242&i=stri...
# ..                                                 ...
# 995  https://www.amazon.it/s?k=9780553278743&i=stri...
# 996  https://www.amazon.it/s?k=9780812536355&i=stri...
# 997  https://www.amazon.it/s?k=9780007157174&i=stri...
# 998  https://www.amazon.it/s?k=9780316098106&i=stri...
# 999  https://www.amazon.it/s?k=9780765333513&i=stri...
#
# [1000 rows x 19 columns]

# %%
meta['Genere_Suggerito'][0]
# Out:
# "['Childrens\\n4,244 users', 'Childrens > Picture Books\\n4,043 users', 'Fiction\\n2,173 users', 'Classics\\n2,103 users', 'Fantasy\\n1,898 users', 'Adventure\\n405 users', '', '', '']"

# %%
#SCRAPING TRAMITE GOODREADS SCRAPER ANTONIAK

# %%
#obiettivo: capire come sfruttare questo scraping per creare le liste che poi ti permettono di fare il dataframe

# %%
#SCRAPING MARIA ANTONIAK

# %%
import argparse
from collections import Counter
from datetime import datetime
import json
import os
import regex as re
import time
import bs4
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException, ElementClickInterceptedException, ElementNotVisibleException, StaleElementReferenceException
from selenium.webdriver.support.ui import Select
from urllib.request import urlopen
from urllib.error import HTTPError
import credentials
from selenium.webdriver.common.by import By
import pandas as pd
from chromedriver_py import binary_path 
import geckodriver_autoinstaller
PATH='C:\\Users\\aless\\OneDrive\\Desktop\\Laurea_magistrale\\Tesi\\chromedriver.exe'
driver = webdriver.Chrome(PATH)

# %%
import pandas as pd
meta_en=pd.read_csv("C:\\Users\\aless\\OneDrive\\Desktop\\Laurea_magistrale\\Tesi\\Dati\\Dati_English\\metadati_EN.csv")
meta_en
# Out:
#      Unnamed: 0  index        Genere  \
# 0             0      0  Children_Lit
# 1             1      1  Children_Lit
# 2             2      2  Children_Lit
# 3             3      3  Children_Lit
# 4             4      4  Children_Lit
# ..          ...    ...           ...
# 995         995   1063         Scify
# 996         996   1064         Scify
# 997         997   1065         Scify
# 998         998   1066         Scify
# 999         999   1067         Scify
#
#                                       Genere_Suggerito  \
# 0    ['Childrens\n4,244 users', 'Childrens > Pictur...
# 1    ['Childrens\n4,125 users', 'Childrens > Pictur...
# 2    ['Childrens\n3,957 users', 'Fiction\n3,617 use...
# 3    ['Classics\n18,253 users', 'Fiction\n5,704 use...
# 4    ['Childrens\n3,071 users', 'Fantasy\n2,796 use...
# ..                                                 ...
# 995  ['Science Fiction\n1,076 users', 'Fiction\n508...
# 996  ['Science Fiction\n1,069 users', 'Fiction\n357...
# 997  ['Science Fiction\n1,066 users', 'Fiction\n1,0...
# 998  ['Science Fiction\n1,065 users', 'Fiction\n410...
# 999  ['Science Fiction\n1,058 users', 'Fiction\n227...
#
#                                               Pud_Data  \
# 0    Published 2000 by Red Fox (first published Apr...
# 1    Published October 7th 1964 by HarperCollins Pu...
# 2    Published June 1st 1998 by Puffin Books (first...
# 3    Published September 1st 1998 by Children's Cla...
# 4    Published September 10th 2002 by Alfred A. Kno...
# ..                                                 ...
# 995  Published December 1997 by Spectra/Bantam Book...
# 996  Published January 15th 2000 by Tor Science Fic...
# 997  Published December 5th 2005 by HarperCollins P...
# 998                   Published July 7th 2015 by Orbit
# 999  Published May 14th 2013 by Tor Books (first pu...
#
#                          Title                   Author           ISBN  \
# 0    Where the Wild Things Are           Maurice Sendak  9780099408390
# 1              The Giving Tree         Shel Silverstein  9780060256654
# 2                      Matilda               Roald Dahl  9780141301068
# 3            The Secret Garden  Frances Hodgson Burnett  9780517189603
# 4    James and the Giant Peach               Roald Dahl  9780375814242
# ..                         ...                      ...            ...
# 995                The Postman               David Brin  9780553278743
# 996      A Deepness in the Sky             Vernor Vinge  9780812536355
# 997      That Hideous Strength               C.S. Lewis  9780007157174
# 998                     Aurora     Kim Stanley Robinson  9780316098106
# 999         The Human Division              John Scalzi  9780765333513
#
#     Num_Pages_GR  Stars_GR                       Distr_Rat_GR  N_Votes_GR  \
# 0             38      4.22  ['53%', '25%', '14%', '5%', '3%']      884675
# 1             64      4.37  ['61%', '22%', '10%', '3%', '3%']      978948
# 2            240      4.32  ['53%', '31%', '13%', '2%', '1%']      741229
# 3            331      4.13  ['43%', '34%', '17%', '4%', '2%']      984296
# 4            146      4.01  ['38%', '34%', '21%', '5%', '2%']      414915
# ..           ...       ...                                ...         ...
# 995          321      3.90  ['29%', '40%', '24%', '5%', '2%']       34029
# 996          775      4.30  ['50%', '34%', '12%', '3%', '1%']       31799
# 997          534      3.88  ['34%', '33%', '23%', '7%', '3%']       34925
# 998          466      3.76  ['25%', '40%', '24%', '8%', '3%']       23091
# 999          431      4.07  ['34%', '45%', '17%', '3%', '1%']       30718
#
#      N_Reviews_GR                                            GR_link  \
# 0           12480  https://www.goodreads.com/book/show/19543.Wher...
# 1           19120  https://www.goodreads.com/book/show/370493.The...
# 2           18376  https://www.goodreads.com/book/show/39988.Matilda
# 3           21409  https://www.goodreads.com/book/show/2998.The_S...
# 4            7540  https://www.goodreads.com/book/show/6689.James...
# ..            ...                                                ...
# 995          1387  https://www.goodreads.com/book/show/889284.The...
# 996          1075  https://www.goodreads.com/book/show/226004.A_D...
# 997          2091  https://www.goodreads.com/book/show/100933.Tha...
# 998          2709  https://www.goodreads.com/book/show/23197269-a...
# 999          1615  https://www.goodreads.com/book/show/15698479-t...
#
#      Stars_AZ                       Distr_Rat_AZ  N_Votes_AZ  N_Reviews_AZ  \
# 0         4.9    ['92%', '5%', '2%', '1%', '1%']     23220.0        3003.0
# 1         4.9    ['92%', '5%', '2%', '1%', '1%']     18132.0        3463.0
# 2         4.8    ['86%', '9%', '3%', '1%', '1%']      5422.0        1160.0
# 3         4.6   ['78%', '13%', '5%', '2%', '3%']      8946.0        2478.0
# 4         4.8    ['85%', '9%', '3%', '1%', '2%']      4101.0         838.0
# ..        ...                                ...         ...           ...
# 995       4.4   ['64%', '22%', '9%', '3%', '2%']       670.0         266.0
# 996       4.6   ['72%', '18%', '6%', '3%', '1%']       458.0         228.0
# 997       4.7   ['79%', '12%', '5%', '2%', '1%']       800.0         320.0
# 998       3.9  ['40%', '29%', '16%', '9%', '5%']      1353.0         769.0
# 999       4.4   ['59%', '28%', '9%', '3%', '2%']      1151.0         563.0
#
#                                                AZ_link
# 0    https://www.amazon.it/s?k=9780099408390&i=stri...
# 1    https://www.amazon.it/s?k=9780060256654&i=stri...
# 2    https://www.amazon.it/s?k=9780141301068&i=stri...
# 3    https://www.amazon.it/s?k=9780517189603&i=stri...
# 4    https://www.amazon.it/s?k=9780375814242&i=stri...
# ..                                                 ...
# 995  https://www.amazon.it/s?k=9780553278743&i=stri...
# 996  https://www.amazon.it/s?k=9780812536355&i=stri...
# 997  https://www.amazon.it/s?k=9780007157174&i=stri...
# 998  https://www.amazon.it/s?k=9780316098106&i=stri...
# 999  https://www.amazon.it/s?k=9780765333513&i=stri...
#
# [1000 rows x 19 columns]

# %%
isbn=meta_en['ISBN'].to_list()
title=meta_en['Title'].to_list()
gen=meta_en['Genere'].to_list()
#mylinks=meta_en['GR_link'].to_list()
print(isbn[:10])
print(title[:10])
print(gen[:10])
#print(mylinks[:10])
# Out:
# [9780099408390, 9780060256654, 9780141301068, 9780517189603, 9780375814242, 9780241003008, 9780141311371, 9780060775858, 9780590032490, 9780439206471]
# ['Where the Wild Things Are', 'The Giving Tree', 'Matilda', 'The Secret Garden', 'James and the Giant Peach', 'The Very Hungry Caterpillar', 'The BFG', 'Goodnight Moon', 'The Witches', 'The Bad Beginning']
# ['Children_Lit', 'Children_Lit', 'Children_Lit', 'Children_Lit', 'Children_Lit', 'Children_Lit', 'Children_Lit', 'Children_Lit', 'Children_Lit', 'Children_Lit']

# %%
#creiamo la colonna di bookid
bookid_list=[]
listid=meta_en['GR_link'].to_list()
for el in listid:
    elem=el.split('.')
    ids=re.findall(r'\d+' ,elem[2])[0]
    bookid_list.append(ids)
bookid_list[:10]
# Out:
# ['19543',
#  '370493',
#  '39988',
#  '2998',
#  '6689',
#  '4948',
#  '6319',
#  '32929',
#  '6327',
#  '78411']

# %%
len(bookid_list)
# Out:
# 1000

# %%
RATING_STARS_DICT = {'it was amazing': 5,
                     'really liked it': 4,
                     'liked it': 3,
                     'it was ok': 2,
                     'did not like it': 1,
                     '': None}


def switch_reviews_mode(driver, book_id, sort_order, rating=''):
    """
    Copyright (C) 2019 by Omar Einea: https://github.com/OmarEinea/GoodReadsScraper
    Licensed under GPL v3.0: https://github.com/OmarEinea/GoodReadsScraper/blob/master/LICENSE.md
    Accessed on 2019-12-01.
    """
    edition_reviews=False
    driver.execute_script(
        'document.getElementById("reviews").insertAdjacentHTML("beforeend", \'<a data-remote="true" rel="nofollow"'
        f'class="actionLinkLite loadingLink" data-keep-on-success="true" id="switch{rating}{sort_order}"' +
        f'href="/book/reviews/{book_id}?rating={rating}&sort={sort_order}' +
        ('&edition_reviews=true' if edition_reviews else '') + '">Switch Mode</a>\');' +
        f'document.getElementById("switch{rating}{sort_order}").click()'
    )
    return True


def get_rating(node):
    if len(node.find_all('span', {'class': 'staticStars'})) > 0:
        rating = node.find_all('span', {'class': 'staticStars'})[0]['title']
        return RATING_STARS_DICT[rating]
    return ''


def get_user_name(node):
    if len(node.find_all('a', {'class': 'user'})) > 0:
        return node.find_all('a', {'class': 'user'})[0]['title']
    return ''

def get_user_url(node):
    if len(node.find_all('a', {'class': 'user'})) > 0:
        return node.find_all('a', {'class': 'user'})[0]['href']
    return ''


def get_date(node):
    if len(node.find_all('a', {'class': 'reviewDate createdAt right'})) > 0:
        return node.find_all('a', {'class': 'reviewDate createdAt right'})[0].text
    return ''


def get_text(node):

    display_text = ''
    full_text = ''

    if len(node.find_all('span', {'class': 'readable'})) > 0:
        for child in node.find_all('span', {'class': 'readable'})[0].children:
            if child.name == 'span' and 'style' not in child:
                display_text = child.text
            if child.name == 'span' and 'style' in child and child['style'] == 'display:none':
                full_text = child.text

    if full_text:
        return full_text

    return display_text


def get_num_likes(node):
    if node.find('span', {'class': 'likesCount'}) and len(node.find('span', {'class': 'likesCount'})) > 0:
        likes = node.find('span', {'class': 'likesCount'}).text
        if 'likes' in likes:
            return int(likes.split()[0])
    return 0


def get_shelves(node): 
    shelves = []       
    if node.find('div', {'class': 'uitext greyText bookshelves'}):
        _shelves_node = node.find('div', {'class': 'uitext greyText bookshelves'})
        for _shelf_node in _shelves_node.find_all('a'):
            shelves.append(_shelf_node.text)
    return shelves

def get_id(bookid):
    pattern = re.compile("([^.]+)")
    return pattern.search(bookid).group()

    
def scrape_reviews_on_current_page(driver, url, book_id, sort_order,number):

    reviews = []

    # Pull the page source, load into BeautifulSoup, and find all review nodes.
    source = driver.page_source
    soup = bs4.BeautifulSoup(source, 'lxml')
    nodes = soup.find_all('div', {'class': 'review'})
    #book_title = soup.find(id='bookTitle').text.strip()
    
    # Iterate through and parse the reviews.
    for node in nodes:
        review_id = re.search('[0-9]+', node['id']).group(0)
        reviews.append({#'book_id_title': book_id,
                        #'book_id': get_id(book_id),
                        'Genere': gen[number],
                        'Titolo': title[number],
                        'ISBN': isbn[number],
                        #'review_url': f"https://www.goodreads.com/review/show/{review_id}", 
                        'review_id': review_id, #poi la elimini dal dataframe, serve solo per il controllo duplicati
                        'Rev_Date_GR': get_date(node), 
                        'Rating_GR': get_rating(node), 
                        'Userlist_GR': get_user_name(node),
                        #'user_url': get_user_url(node), 
                        'N_Likes_GR': get_num_likes(node),
                        #'sort_order': sort_order,
                        'Shelves': get_shelves(node),
                        'Rev_Content_GR': get_text(node)})

    return reviews


def check_for_duplicates(reviews):
    review_ids = [r['review_id'] for r in reviews]  
    num_duplicates = len([_id for _id, _count in Counter(review_ids).items() if _count > 1])
    return num_duplicates


def get_reviews_first_ten_pages(driver, book_id, sort_order,number):

    reviews = []
    url = 'https://www.goodreads.com/book/show/' + book_id
    try:
        driver.get(url)
    except:
        time.sleep(3)
        driver.get(url)

    try:
        source = driver.page_source
    except:
        time.sleep(3)
        source = driver.page_source

    try:
        time.sleep(4)
    
        select = Select(driver.find_element_by_name('language_code'))
        select.select_by_value('en')
        time.sleep(4)
    
        # Scrape the first page of reviews.
        reviews = scrape_reviews_on_current_page(driver, url, book_id, sort_order,number)
        #print('Scraped page 1')
        # GoodReads will only load the first 10 pages of reviews.
        # Click through each of the following nine pages and scrape each page.
        page_counter = 2
        while page_counter <=10:
            try:
                if driver.find_element_by_link_text(str(page_counter)):
                    driver.find_element_by_link_text(str(page_counter)).click()
                    time.sleep(3)
                    reviews += scrape_reviews_on_current_page(driver, url, book_id, sort_order,number)
                    #print(f"Scraped page {page_counter}")
                    page_counter += 1
                else:
                    return reviews
            
            except NoSuchElementException:
                if page_counter == 10:
                    try:
                        driver.find_element_by_link_text(str(9)).click()
                        time.sleep(2)
                        continue
                    except:
                        return reviews
                else:
                    try:
                        if driver.find_element(By.CLASS_NAME, 'next_page'):
                            driver.find_element(By.CLASS_NAME, 'next_page').click()
                            continue
                    except NoSuchElementException:
                        #print("'next' button not found either")
                        return reviews
            
            except ElementNotVisibleException:
                #print('ERROR ElementNotVisibleException: Pop-up detected, reloading the page.')
                reviews = get_reviews_first_ten_pages(driver, book_id, sort_order,number)
                return reviews
                        
            except ElementClickInterceptedException:
                #print(f'🚨 ElementClickInterceptedException (Likely a pop-up)🚨\n🔄 Refreshing Goodreads site and skipping problem page {page_counter}🔄')
                driver.get(url)
                time.sleep(3)
                page_counter += 1
                continue
                
            except StaleElementReferenceException:
                #print('ERROR: StaleElementReferenceException\nRefreshing Goodreads site and skipping problem page {page_counter} ')
                driver.get(url)
                time.sleep(3)
                page_counter += 1
                continue
                
    except ElementClickInterceptedException:
                #print(f'🚨 ElementClickInterceptedException (Likely a pop-up)🚨\n🔄 Refreshing Goodreads site and rescraping book🔄')
                driver.get(url)
                time.sleep(3)
                reviews = get_reviews_first_ten_pages(driver, book_id, sort_order,number)
                return reviews
                
    except ElementNotInteractableException:
            #print('🚨 ElementNotInteractableException🚨 \n🔄 Refreshing Goodreads site and rescraping book🔄')
            reviews = get_reviews_first_ten_pages(driver, book_id, sort_order,number)
            return reviews

        
    if check_for_duplicates(reviews) >= 30:
        print(f'ERROR: {check_for_duplicates(reviews)} duplicates found! Re-scraping this book.')
        reviews = get_reviews_first_ten_pages(driver, book_id, sort_order,number)
        return reviews
    else:
        return reviews

    return reviews

# %%
goodreads=[]
number=-1
#sort_order='newest'
for el in bookid_list:
    number+=1
    try:
        try:
            rev=get_reviews_first_ten_pages(driver, el, 'newest',number)
        except NoSuchElementException:
            time.sleep(60*2)
            rev=get_reviews_first_ten_pages(driver, el, 'newest',number)
    except NoSuchElementException:
        time.sleep(60*3)
        rev=get_reviews_first_ten_pages(driver, el, 'newest',number)
        
    print(number)
    print(len(rev))
    print('\n')
    for el in rev:
        goodreads.append(el)
goodreads_data=pd.DataFrame(goodreads)
goodreads_data

# %%
colonne=goodreads_data.columns.to_list()
#print(colonne)
gr_data=goodreads_data.drop_duplicates(subset=colonne[3],keep='first',inplace=False)
gr_data

# %%
gr_data=gr_data.drop('review_id',axis=1) #e altre se serve
gr_data
# Out:
#              Genere                     Titolo           ISBN   Rev_Date_GR  \
# 0      Children_Lit  Where the Wild Things Are  9780099408390  Nov 03, 2007
# 1      Children_Lit  Where the Wild Things Are  9780099408390  Aug 16, 2007
# 2      Children_Lit  Where the Wild Things Are  9780099408390  Sep 11, 2009
# 3      Children_Lit  Where the Wild Things Are  9780099408390  May 16, 2017
# 4      Children_Lit  Where the Wild Things Are  9780099408390  May 14, 2021
# ...             ...                        ...            ...           ...
# 55872       Romance                    Confess  9781501176838  Jun 11, 2021
# 55873       Romance                    Confess  9781501176838  Apr 12, 2018
# 55874       Romance                    Confess  9781501176838  Mar 09, 2015
# 55875       Romance                    Confess  9781501176838  Jul 11, 2015
# 55876       Romance                    Confess  9781501176838  Feb 25, 2020
#
#       Rating_GR     Userlist_GR  N_Likes_GR  \
# 0             5          Nathan         443
# 1             1         fleegan         224
# 2             5           Angie         210
# 3                 Mark Lawrence         169
# 4             5         Swaroop         164
# ...         ...             ...         ...
# 55872         1           fruit          12
# 55873         4           Sara           12
# 55874         4      Donita Luz          12
# 55875         2          Ksenia          12
# 55876         4  Lo Bookfrantic          12
#
#                                                  Shelves  \
# 0                                              [fiction]
# 1                                            [uttercrap]
# 2                                      [2009, childrens]
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 55872                               [finished-but-hated]
# 55873                                        [new-adult]
# 55874  [books-i-own, romance, a-must-have, favorites,...
# 55875  [2015, audiobooks, contemporary, new-adult, au...
# 55876                            [loan-overdrive, audio]
#
#                                           Rev_Content_GR
# 0      I have no doubt that this book damaged me, psy...
# 1      This book is crap, and let me tell you why. Th...
# 2      "Mom. Mom. Mo-om. Mom. MOM!"My mom whips aroun...
# 3      My copy of this book is over fifty years old. ...
# 4      Brilliant! so comforting, so wild, so much fun...
# ...                                                  ...
# 55872  I’m disappointed. Confess was just boring, I d...
# 55873  *4.75This was my first Coleen Hoover book and ...
# 55874  \n\n"It's amazing how much distance one truth ...
# 55875  Story rating: 2 StarsAudio rating: 3.5 StarsOv...
# 55876  This was a great story! It wasn’t as emotional...
#
# [55877 rows x 9 columns]

# %%
from langdetect import detect
lang=[]
for index, row in gr_data['Rev_Content_GR'].iteritems():
    try:
        language = detect(row) #detecting each row
        lang.append(language)
    except:
        lang.append('not found')
lang[:10]
# Out:
# ['en', 'en', 'en', 'en', 'en', 'en', 'fa', 'en', 'en', 'en']

# %%
gr_data['Language_GR']=lang
gr_data
# Out:
#              Genere                     Titolo           ISBN   Rev_Date_GR  \
# 0      Children_Lit  Where the Wild Things Are  9780099408390  Nov 03, 2007
# 1      Children_Lit  Where the Wild Things Are  9780099408390  Aug 16, 2007
# 2      Children_Lit  Where the Wild Things Are  9780099408390  Sep 11, 2009
# 3      Children_Lit  Where the Wild Things Are  9780099408390  May 16, 2017
# 4      Children_Lit  Where the Wild Things Are  9780099408390  May 14, 2021
# ...             ...                        ...            ...           ...
# 55872       Romance                    Confess  9781501176838  Jun 11, 2021
# 55873       Romance                    Confess  9781501176838  Apr 12, 2018
# 55874       Romance                    Confess  9781501176838  Mar 09, 2015
# 55875       Romance                    Confess  9781501176838  Jul 11, 2015
# 55876       Romance                    Confess  9781501176838  Feb 25, 2020
#
#       Rating_GR     Userlist_GR  N_Likes_GR  \
# 0             5          Nathan         443
# 1             1         fleegan         224
# 2             5           Angie         210
# 3                 Mark Lawrence         169
# 4             5         Swaroop         164
# ...         ...             ...         ...
# 55872         1           fruit          12
# 55873         4           Sara           12
# 55874         4      Donita Luz          12
# 55875         2          Ksenia          12
# 55876         4  Lo Bookfrantic          12
#
#                                                  Shelves  \
# 0                                              [fiction]
# 1                                            [uttercrap]
# 2                                      [2009, childrens]
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 55872                               [finished-but-hated]
# 55873                                        [new-adult]
# 55874  [books-i-own, romance, a-must-have, favorites,...
# 55875  [2015, audiobooks, contemporary, new-adult, au...
# 55876                            [loan-overdrive, audio]
#
#                                           Rev_Content_GR Language_GR
# 0      I have no doubt that this book damaged me, psy...          en
# 1      This book is crap, and let me tell you why. Th...          en
# 2      "Mom. Mom. Mo-om. Mom. MOM!"My mom whips aroun...          en
# 3      My copy of this book is over fifty years old. ...          en
# 4      Brilliant! so comforting, so wild, so much fun...          en
# ...                                                  ...         ...
# 55872  I’m disappointed. Confess was just boring, I d...          en
# 55873  *4.75This was my first Coleen Hoover book and ...          en
# 55874  \n\n"It's amazing how much distance one truth ...          en
# 55875  Story rating: 2 StarsAudio rating: 3.5 StarsOv...          en
# 55876  This was a great story! It wasn’t as emotional...          en
#
# [55877 rows x 10 columns]

# %%
gr_data=gr_data[gr_data['Language_GR'] == 'en']
gr_data=gr_data.reset_index()
gr_data
# Out:
#        index        Genere                     Titolo           ISBN  \
# 0          0  Children_Lit  Where the Wild Things Are  9780099408390
# 1          1  Children_Lit  Where the Wild Things Are  9780099408390
# 2          2  Children_Lit  Where the Wild Things Are  9780099408390
# 3          3  Children_Lit  Where the Wild Things Are  9780099408390
# 4          4  Children_Lit  Where the Wild Things Are  9780099408390
# ...      ...           ...                        ...            ...
# 54975  55872       Romance                    Confess  9781501176838
# 54976  55873       Romance                    Confess  9781501176838
# 54977  55874       Romance                    Confess  9781501176838
# 54978  55875       Romance                    Confess  9781501176838
# 54979  55876       Romance                    Confess  9781501176838
#
#         Rev_Date_GR Rating_GR     Userlist_GR  N_Likes_GR  \
# 0      Nov 03, 2007         5          Nathan         443
# 1      Aug 16, 2007         1         fleegan         224
# 2      Sep 11, 2009         5           Angie         210
# 3      May 16, 2017             Mark Lawrence         169
# 4      May 14, 2021         5         Swaroop         164
# ...             ...       ...             ...         ...
# 54975  Jun 11, 2021         1           fruit          12
# 54976  Apr 12, 2018         4           Sara           12
# 54977  Mar 09, 2015         4      Donita Luz          12
# 54978  Jul 11, 2015         2          Ksenia          12
# 54979  Feb 25, 2020         4  Lo Bookfrantic          12
#
#                                                  Shelves  \
# 0                                              [fiction]
# 1                                            [uttercrap]
# 2                                      [2009, childrens]
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 54975                               [finished-but-hated]
# 54976                                        [new-adult]
# 54977  [books-i-own, romance, a-must-have, favorites,...
# 54978  [2015, audiobooks, contemporary, new-adult, au...
# 54979                            [loan-overdrive, audio]
#
#                                           Rev_Content_GR Language_GR
# 0      I have no doubt that this book damaged me, psy...          en
# 1      This book is crap, and let me tell you why. Th...          en
# 2      "Mom. Mom. Mo-om. Mom. MOM!"My mom whips aroun...          en
# 3      My copy of this book is over fifty years old. ...          en
# 4      Brilliant! so comforting, so wild, so much fun...          en
# ...                                                  ...         ...
# 54975  I’m disappointed. Confess was just boring, I d...          en
# 54976  *4.75This was my first Coleen Hoover book and ...          en
# 54977  \n\n"It's amazing how much distance one truth ...          en
# 54978  Story rating: 2 StarsAudio rating: 3.5 StarsOv...          en
# 54979  This was a great story! It wasn’t as emotional...          en
#
# [54980 rows x 11 columns]

# %%
nrighe/250

# %%
gr_data.to_csv('goodreads_ant_0_250.csv')
